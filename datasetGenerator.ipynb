# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# # modèle de fonctionnement des prompts avec un texte
# text = f"""
# You should express what you want a model to do by \ 
# providing instructions that are as clear and \ 
# specific as you can possibly make them. \ 
# This will guide the model towards the desired output, \ 
# and reduce the chances of receiving irrelevant \ 
# or incorrect responses. Don't confuse writing a \ 
# clear prompt with writing a short prompt. \ 
# In many cases, longer prompts provide more clarity \ 
# and context for the model, which can lead to \ 
# more detailed and relevant outputs.
# """
# prompt = f"""
# Summarize the text delimited by triple backticks \ 
# into a single sentence.
# ```{text}```
# """
# response = get_completion(prompt)
# print(response)

# %%
# # text generation
# prompt = "Generate a short text in French. \
# Once generated, look for proper names and company names in it. \
# Add the mention {first name} after each first name, add the mention {last name} after each last name, and add the mention {company name} after each company name."
# response = get_completion(prompt)
# print(response)

# %%
# # text generation
# prompt = f"""
# Génère un court texte en Français. \
# Une fois le texte généré, recherche tous les prénoms, noms de famille et noms d'entreprises dans ce texte. \
# Ajoute la mention <first name> après chaque occurrence de chaque prénom ; ajoute la mention <last name> après chaque occurrence de chaque nom de famille ; ajoute la mention mention <company name> après chaque occurrence de chaque nom d'entreprise."
# """
# response = get_completion(prompt)
# print(response)
# Out:
# Il était une fois, dans la petite ville de Sainte-Marie, un jeune homme nommé Pierre. Pierre était un étudiant brillant et passionné par les sciences. Il rêvait de devenir un grand chercheur et de faire des découvertes qui changeraient le monde.
#
# Un jour, Pierre rencontra une jeune femme prénommée Sophie. Sophie était une artiste talentueuse et douce. Elle avait une voix envoûtante et peignait des tableaux magnifiques. Pierre tomba immédiatement amoureux d'elle et ils commencèrent à se fréquenter.
#
# Pendant ce temps, dans le quartier voisin, vivait une famille renommée, les Dupont. Les Dupont étaient des entrepreneurs prospères et possédaient une entreprise de construction. Ils étaient respectés dans la communauté et leur nom était synonyme de succès.
#
# Pierre et Sophie décidèrent de fonder leur propre entreprise. Ils voulaient combiner leurs talents et créer quelque chose d'unique. Ils appelèrent leur entreprise "Les Innovateurs". Ils espéraient que leur entreprise deviendrait un symbole d'innovation et de créativité.
#
# Au fil des années, "Les Innovateurs" devint une entreprise prospère. Pierre et Sophie travaillaient dur pour réaliser leurs rêves et leur entreprise était devenue une référence dans leur domaine. Ils étaient fiers de leur réussite et de l'impact qu'ils avaient sur la société.
#
# Pierre Dupont, le fils de la famille Dupont, entendit parler de "Les Innovateurs" et fut impressionné par leur travail. Il décida de les contacter pour discuter d'une éventuelle collaboration. Pierre et Sophie étaient ravis de cette opportunité et acceptèrent avec enthousiasme.
#
# Ainsi, Pierre Dupont rejoignit l'équipe des Innovateurs et apporta son expertise en gestion et en finance. Ensemble, ils firent de grandes avancées et leur entreprise devint encore plus prospère.
#
# Dans cette histoire, Pierre, Sophie, les Dupont et "Les Innovateurs" sont les protagonistes. Chaque fois que leur nom apparaît, nous ajoutons la mention <first name> pour les prénoms, <last name> pour les noms de famille et <company name> pour le nom de l'entreprise.

# %%
prompt = f"""
Your task is to perform the actions described below:
1 - Generate a short text in French.
2 - Once generated, look for proper names.
3 - In the text from step 1, add the mention <first name> after each first name, add the mention <last name> after each last name.
Here is an example of what the output should look like. Don't make your text about a similar topic or it will be rejected:
```
Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
```
"""
response = get_completion(prompt)
print(response)
# Out:
# Voici une histoire captivante sur une jeune fille nommée Camille <prénom>. Elle vivait dans une petite ville appelée Saint-Martin <nom de famille>. Camille <prénom> aimait lire des livres et passer du temps avec sa famille. Un jour, elle rencontra un garçon curieux nommé Lucas <prénom>. Ils devinrent rapidement les meilleurs amis. Camille <prénom> et Lucas <prénom> passaient leurs journées à explorer la nature et à s'amuser ensemble. Cependant, un jour, Camille <prénom> tomba malade et Lucas <prénom> fut très inquiet. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Camille <prénom> se rétablit rapidement. Lucas <prénom> était soulagé de voir son amie en bonne santé. Depuis ce jour, Camille <prénom> et Lucas <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
