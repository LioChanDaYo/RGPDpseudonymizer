# %%
import pandas as pd
# create an empty dataframe with only one column named "text"
df = pd.DataFrame(columns=["text"])

# %%
# make a function to read a string in a variable and concatenate it to the dataframe
def add_to_df(text):
    global df
    df = pd.concat([df, pd.DataFrame([text], columns=["text"])], ignore_index=True)

# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.8, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# # modèle de fonctionnement des prompts avec un texte
# text = f"""
# You should express what you want a model to do by \ 
# providing instructions that are as clear and \ 
# specific as you can possibly make them. \ 
# This will guide the model towards the desired output, \ 
# and reduce the chances of receiving irrelevant \ 
# or incorrect responses. Don't confuse writing a \ 
# clear prompt with writing a short prompt. \ 
# In many cases, longer prompts provide more clarity \ 
# and context for the model, which can lead to \ 
# more detailed and relevant outputs.
# """
# prompt = f"""
# Summarize the text delimited by triple backticks \ 
# into a single sentence.
# ```{text}```
# """
# response = get_completion(prompt)
# print(response)

# %%
# # text generation
# prompt = f"""
# Génère un court texte en Français. \
# Une fois le texte généré, recherche tous les prénoms, noms de famille et noms d'entreprises dans ce texte. \
# Ajoute la mention <first name> après chaque occurrence de chaque prénom ; ajoute la mention <last name> après chaque occurrence de chaque nom de famille ; ajoute la mention mention <company name> après chaque occurrence de chaque nom d'entreprise."
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to perform the actions described below:
# 1 - Generate a short text in French.
# 2 - Once generated, look for proper names.
# 3 - In the text from step 1, add the mention <first name> after each first name, add the mention <last name> after each last name.
# Here is an example of what the output should look like. Don't make your text about a similar topic or it will be rejected:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
# Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# add_to_df(response)
# df.head()

# %%
# # a function that make the prompt from two lists of first names and last names
# def makePrompt(first_names,last_names,topic,style,beginning):
#     prompt = f"""
#     Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
#     Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
#     ```
#     Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
#     ```
#     The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
#     the first names should be different from the following list: {first_names}
#     the last names should be different from the following list: {last_names}
#     the topic should be different from the following list: {topic}
#     the style should be different from the following list: {style}
#     the beginning should be different from the following list: {beginning}
#     Here are a few suggestions of topics: judiciaire, politique, sport, économie, santé, culture, technologie, environnement, éducation, société, international, sciences, médias, religion, faits divers, people, etc.
#     Here are few suggestions of styles: informatif, narratif, descriptif, argumentatif, explicatif, injonctif, poétique, humoristique, etc.
#     The output should be a JSON object with the following keys: text, first_names, last_names, topics, styles, beginnings.
#     """
#     return prompt

# %%
# def makePrompt(first_names,last_names,topic):
#     prompt = f"""
#     Your task is to write a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
#     the first names should be different from the following list: {first_names}
#     the last names should be different from the following list: {last_names}
#     the topic should be different from the following list: {topic}
#     Here is an example of what the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
#     ```
#     Voici une histoire passionnante sur un jeune garçon nommé Pierre <first name>. Il vivait dans un petit village appelé Saint-Étienne. Pierre <first name> Leblanc <last name> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <first name>. Ils devinrent rapidement les meilleurs amis. Pierre <first name> et Sophie <first name> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <first name> tomba malade et Sophie <first name> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <first name> se rétablit rapidement. Sophie <first name> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <first name> et Sophie <first name> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
#     ```
#     The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
#     The output should be a JSON object with the following keys: text, first_names, last_names, topics.
#     """
#     return prompt

# %%
def makePrompt(first_names,last_names,topic,beginning):
    prompt = f"""
    Your task is to write a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
    the first names should NOT be any element from the following list: {first_names}
    the last names should NOT be any element from the following list: {last_names}
    the topic should NOT be any element from the following list: {topic}
    the beginning should NOT be any element from the following list: {beginning}
    The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example below.
    The output should ONLY be a JSON object with the following keys: text, first_names, last_names, topics, beginnings.
    Here is an example of what the text in the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
    ```
    Voici une histoire passionnante sur un jeune garçon nommé Pierre <first name>. Il vivait dans un petit village appelé Saint-Étienne. Pierre <first name> Leblanc <last name> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <first name>. Ils devinrent rapidement les meilleurs amis. Pierre <first name> et Sophie <first name> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <first name> tomba malade et Sophie <first name> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <first name> se rétablit rapidement. Sophie <first name> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <first name> et Sophie <first name> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
    ```
    """
    return prompt

# %%
import json
def is_json(myjson):
  try:
    json.loads(myjson)
  except ValueError as e:
    return False
  return True

first_names = ["Pierre","Sophie"]
last_names = ["Leblanc"]
topic = []
beginning = ["Voici une histoire"]

# %%
# add texts in a loop to dataframe
for i in range(10):
    prompt = makePrompt(first_names,last_names,topic,beginning)
    response = get_completion(prompt)
    print("réponse complète : " + response)
    if is_json(response):
        response = json.loads(response)
        text = response["text"]
        print("le texte est : " + text)
        # get the contents of the "first_names" and "last_names" keys from the JSON object in the response and append them to the lists
        first_names = first_names + response["first_names"]
        last_names = last_names + response["last_names"]
        topic = topic + response["topics"]
        beginning = beginning + response["beginnings"]
        print("les prénoms sont : ")
        print(first_names)
        print("les noms de famille sont : ")
        print(last_names)
        print("les sujets sont : ")
        print(topic)
        print("les débuts sont : ")
        print(beginning)
    else:
        text = response
        print(text)
    add_to_df(text)

df.head()
# Out:
# réponse complète : {
#     "text": "Voici un court texte sur une femme nommée Emma <first name>. Elle était une artiste talentueuse et passionnée par la peinture. Emma <first name> avait toujours été fascinée par les couleurs vives et les formes abstraites, et cela se reflétait dans ses œuvres d'art. Son style unique et sa créativité lui ont valu de nombreuses reconnaissances et succès dans le monde de l'art. Emma <first name> aimait passer des heures dans son atelier, laissant libre cours à son imagination et créant des toiles magnifiques. Son travail a été exposé dans de nombreuses galeries d'art à travers le monde. Les gens étaient captivés par la beauté et l'émotion que ses peintures transmettaient. Emma <first name> était une âme passionnée et inspirante, et son art continuera de toucher les cœurs des gens pour les années à venir.",
#     "first_names": ["Emma", "Julien", "Maria", "Liam", "Sofia"],
#     "last_names": ["Dubois", "Gonzalez", "Taylor", "Lopez", "Cohen"],
#     "topics": ["la musique", "la cuisine", "les voyages", "la littérature", "le sport"],
#     "beginnings": ["Il était une fois", "Dans un monde lointain", "Au cœur d'une ville animée", "Dans un petit village pittoresque", "Au sommet d'une montagne majestueuse"]
# }
# le texte est : Voici un court texte sur une femme nommée Emma <first name>. Elle était une artiste talentueuse et passionnée par la peinture. Emma <first name> avait toujours été fascinée par les couleurs vives et les formes abstraites, et cela se reflétait dans ses œuvres d'art. Son style unique et sa créativité lui ont valu de nombreuses reconnaissances et succès dans le monde de l'art. Emma <first name> aimait passer des heures dans son atelier, laissant libre cours à son imagination et créant des toiles magnifiques. Son travail a été exposé dans de nombreuses galeries d'art à travers le monde. Les gens étaient captivés par la beauté et l'émotion que ses peintures transmettaient. Emma <first name> était une âme passionnée et inspirante, et son art continuera de toucher les cœurs des gens pour les années à venir.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse"]
# réponse complète : {
#     "text": "Voici une histoire fascinante sur une jeune femme nommée Nina <first name>. Elle vivait dans une petite ville appelée Sainte-Marie. Nina <first name> González <last name> aimait voyager et découvrir de nouvelles cultures. Un jour, lors d'un voyage en Inde, elle rencontra un homme charmant nommé Raj <first name>. Ils devinrent rapidement amis et commencèrent à explorer ensemble les merveilles de l'Inde. Nina <first name> et Raj <first name> visitaient des temples anciens, dégustaient de délicieux plats indiens et dansaient au son de la musique traditionnelle. Cependant, un jour, Nina <first name> tomba malade et Raj <first name> fut très inquiet. Heureusement, grâce aux soins attentifs des médecins et à l'amour de Raj <first name>, Nina <first name> se rétablit rapidement. Raj <first name> était soulagé de voir son amie en bonne santé. Depuis ce jour, Nina <first name> et Raj <first name> sont inséparables et partagent de nombreux moments de bonheur ensemble.",
#     "first_names": ["Nina", "Raj"],
#     "last_names": ["González"],
#     "topics": ["les voyages", "la culture indienne"],
#     "beginnings": ["Il était une fois", "Au cœur d'une ville animée"]
# }
# le texte est : Voici une histoire fascinante sur une jeune femme nommée Nina <first name>. Elle vivait dans une petite ville appelée Sainte-Marie. Nina <first name> González <last name> aimait voyager et découvrir de nouvelles cultures. Un jour, lors d'un voyage en Inde, elle rencontra un homme charmant nommé Raj <first name>. Ils devinrent rapidement amis et commencèrent à explorer ensemble les merveilles de l'Inde. Nina <first name> et Raj <first name> visitaient des temples anciens, dégustaient de délicieux plats indiens et dansaient au son de la musique traditionnelle. Cependant, un jour, Nina <first name> tomba malade et Raj <first name> fut très inquiet. Heureusement, grâce aux soins attentifs des médecins et à l'amour de Raj <first name>, Nina <first name> se rétablit rapidement. Raj <first name> était soulagé de voir son amie en bonne santé. Depuis ce jour, Nina <first name> et Raj <first name> sont inséparables et partagent de nombreux moments de bonheur ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée"]
# réponse complète : {
#     "text": "Il y avait une fois un garçon curieux qui s'appelait Maxime <first name>. Il habitait dans un quartier tranquille de Paris. Maxime <first name> Taylor <last name> aimait passer son temps à lire et à explorer le monde. Un jour, lors d'une de ses aventures, il rencontra une fille fascinante nommée Leyla <first name>. Ils se lièrent d'amitié instantanément. Maxime <first name> et Leyla <first name> partageaient leur passion pour les voyages et la découverte de nouvelles cultures. Ensemble, ils visitèrent de nombreux pays et apprirent beaucoup de choses intéressantes. Cependant, un jour, Maxime <first name> se perdit dans une forêt dense et Leyla <first name> fut très inquiète. Heureusement, Maxime <first name> retrouva son chemin grâce à son sens de l'orientation et à l'aide d'un groupe de randonneurs. Leyla <first name> était soulagée de voir son ami sain et sauf. Depuis ce jour, Maxime <first name> et Leyla <first name> étaient inséparables et partageaient de nombreuses aventures ensemble.",
#     "first_names": ["Maxime", "Leyla"],
#     "last_names": ["Taylor"],
#     "topics": ["les livres", "les voyages"],
#     "beginnings": ["Il y avait une fois", "Il y avait un garçon curieux"]
# }
# le texte est : Il y avait une fois un garçon curieux qui s'appelait Maxime <first name>. Il habitait dans un quartier tranquille de Paris. Maxime <first name> Taylor <last name> aimait passer son temps à lire et à explorer le monde. Un jour, lors d'une de ses aventures, il rencontra une fille fascinante nommée Leyla <first name>. Ils se lièrent d'amitié instantanément. Maxime <first name> et Leyla <first name> partageaient leur passion pour les voyages et la découverte de nouvelles cultures. Ensemble, ils visitèrent de nombreux pays et apprirent beaucoup de choses intéressantes. Cependant, un jour, Maxime <first name> se perdit dans une forêt dense et Leyla <first name> fut très inquiète. Heureusement, Maxime <first name> retrouva son chemin grâce à son sens de l'orientation et à l'aide d'un groupe de randonneurs. Leyla <first name> était soulagée de voir son ami sain et sauf. Depuis ce jour, Maxime <first name> et Leyla <first name> étaient inséparables et partageaient de nombreuses aventures ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux']
# réponse complète : {
#   "text": "Il était une fois un homme énigmatique nommé Luca <first name>. Il était connu pour sa sagesse et sa capacité à résoudre les problèmes les plus complexes. Luca <first name> González <last name> vivait dans un petit village tranquille au cœur de la forêt. Un jour, une jeune femme timide nommée Aisha <first name> Taylor <last name> vint le trouver. Aisha <first name> avait un problème délicat et elle savait que Luca <first name> était le seul qui pourrait l'aider. Elle lui raconta son histoire et Luca <first name> l'écouta attentivement, sautant parfois dans la conversation avec des questions perspicaces. Avec sa sagesse et son intuition, Luca <first name> proposa une solution brillante à Aisha <first name>. Elle était émerveillée par l'intelligence et l'empathie de Luca <first name>. Depuis ce jour, Luca <first name> et Aisha <first name> étaient amis et partageaient des moments précieux ensemble.",
#   "first_names": ["Luca", "Aisha"],
#   "last_names": ["González", "Taylor"],
#   "topics": ["l'astronomie", "la philosophie"],
#   "beginnings": ["Il était une fois un homme énigmatique nommé Luca <first name>.", "Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>."]
# }
# le texte est : Il était une fois un homme énigmatique nommé Luca <first name>. Il était connu pour sa sagesse et sa capacité à résoudre les problèmes les plus complexes. Luca <first name> González <last name> vivait dans un petit village tranquille au cœur de la forêt. Un jour, une jeune femme timide nommée Aisha <first name> Taylor <last name> vint le trouver. Aisha <first name> avait un problème délicat et elle savait que Luca <first name> était le seul qui pourrait l'aider. Elle lui raconta son histoire et Luca <first name> l'écouta attentivement, sautant parfois dans la conversation avec des questions perspicaces. Avec sa sagesse et son intuition, Luca <first name> proposa une solution brillante à Aisha <first name>. Elle était émerveillée par l'intelligence et l'empathie de Luca <first name>. Depuis ce jour, Luca <first name> et Aisha <first name> étaient amis et partageaient des moments précieux ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor', 'González', 'Taylor']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages', "l'astronomie", 'la philosophie']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Il était une fois un homme énigmatique nommé Luca <first name>.', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>.']
# réponse complète : {
#     "text": "Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine. Léa <first name> Martin <last name> aimait passer du temps à lire des livres et à explorer la nature. Un jour, elle découvrit un vieux grimoire dans la bibliothèque de sa grand-mère. Le grimoire était rempli de sorts et de potions magiques. Léa <first name> était fascinée par la magie et décida d'apprendre à l'utiliser. Au fur et à mesure de ses expérimentations, Léa <first name> devint de plus en plus douée en magie. Elle réussit à guérir sa meilleure amie, Nina <first name>, d'une maladie grave en utilisant un sort de guérison puissant. Nina <first name> était émerveillée par les talents magiques de Léa <first name>. Depuis ce jour, Léa <first name> et Nina <first name> étaient inséparables et partageaient de nombreuses aventures magiques ensemble.",
#     "first_names": ["Léa", "Nina"],
#     "last_names": ["Martin"],
#     "topics": ["la magie"],
#     "beginnings": ["Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine."]
# }
# le texte est : Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine. Léa <first name> Martin <last name> aimait passer du temps à lire des livres et à explorer la nature. Un jour, elle découvrit un vieux grimoire dans la bibliothèque de sa grand-mère. Le grimoire était rempli de sorts et de potions magiques. Léa <first name> était fascinée par la magie et décida d'apprendre à l'utiliser. Au fur et à mesure de ses expérimentations, Léa <first name> devint de plus en plus douée en magie. Elle réussit à guérir sa meilleure amie, Nina <first name>, d'une maladie grave en utilisant un sort de guérison puissant. Nina <first name> était émerveillée par les talents magiques de Léa <first name>. Depuis ce jour, Léa <first name> et Nina <first name> étaient inséparables et partageaient de nombreuses aventures magiques ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha', 'Léa', 'Nina']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor', 'González', 'Taylor', 'Martin']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages', "l'astronomie", 'la philosophie', 'la magie']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Il était une fois un homme énigmatique nommé Luca <first name>.', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>.', 'Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine.']
# réponse complète : {
#   "text": "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>. Il travaillait dur pour réussir dans le monde des affaires et était respecté par ses collègues. David <first name> avait une passion pour la technologie et aimait suivre les dernières tendances. Un jour, lors d'une conférence internationale, il rencontra une femme intelligente et talentueuse nommée Olivia <first name>. Ils partagèrent leur amour pour l'innovation et la créativité. David <first name> et Olivia <first name> commencèrent à travailler ensemble sur un projet révolutionnaire qui changerait le monde de l'industrie technologique. Leur collaboration était fructueuse et leur projet attira l'attention des investisseurs. Grâce à leur dévouement et à leur expertise, David <first name> et Olivia <first name> réussirent à lancer leur entreprise avec succès. Ils réalisèrent leur rêve de construire une entreprise prospère qui contribuerait à l'avancement de la technologie. David <first name> et Olivia <first name> étaient fiers de leur accomplissement et de l'équipe solide qu'ils avaient formée. Leur histoire inspira de nombreux jeunes entrepreneurs à suivre leurs passions et à poursuivre leurs rêves.",
#   "first_names": ["David", "Olivia"],
#   "last_names": ["Lefebvre", "Garcia"],
#   "topics": ["l'entrepreneuriat", "les nouvelles technologies"],
#   "beginnings": ["Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>.", "Il était une fois dans un monde connecté, une femme brillante du nom d'Olivia <first name>."]
# }
# le texte est : Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>. Il travaillait dur pour réussir dans le monde des affaires et était respecté par ses collègues. David <first name> avait une passion pour la technologie et aimait suivre les dernières tendances. Un jour, lors d'une conférence internationale, il rencontra une femme intelligente et talentueuse nommée Olivia <first name>. Ils partagèrent leur amour pour l'innovation et la créativité. David <first name> et Olivia <first name> commencèrent à travailler ensemble sur un projet révolutionnaire qui changerait le monde de l'industrie technologique. Leur collaboration était fructueuse et leur projet attira l'attention des investisseurs. Grâce à leur dévouement et à leur expertise, David <first name> et Olivia <first name> réussirent à lancer leur entreprise avec succès. Ils réalisèrent leur rêve de construire une entreprise prospère qui contribuerait à l'avancement de la technologie. David <first name> et Olivia <first name> étaient fiers de leur accomplissement et de l'équipe solide qu'ils avaient formée. Leur histoire inspira de nombreux jeunes entrepreneurs à suivre leurs passions et à poursuivre leurs rêves.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha', 'Léa', 'Nina', 'David', 'Olivia']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor', 'González', 'Taylor', 'Martin', 'Lefebvre', 'Garcia']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages', "l'astronomie", 'la philosophie', 'la magie', "l'entrepreneuriat", 'les nouvelles technologies']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Il était une fois un homme énigmatique nommé Luca <first name>.', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>.', 'Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine.', "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>.", "Il était une fois dans un monde connecté, une femme brillante du nom d'Olivia <first name>."]
# réponse complète : {
#   "text": "Voici une histoire fascinante sur une jeune fille nommée Ava <first name>. Elle vivait dans une petite ville tranquille appelée Dupont-sur-Mer. Ava <first name> Thompson <last name> aimait passer son temps à lire des livres et à écrire des histoires. Elle rêvait de devenir écrivaine un jour. Un après-midi ensoleillé, Ava <first name> se promenait dans le parc quand elle rencontra un garçon curieux nommé Noah <first name>. Noah <first name> Ramirez <last name> était passionné par l'astronomie et adorait observer les étoiles. Ava <first name> et Noah <first name> se lièrent d'amitié instantanément et commencèrent à explorer leur passion commune pour les étoiles. Ils passaient des heures à observer le ciel nocturne et à discuter de l'univers infini. Grâce à leur amitié, Ava <first name> et Noah <first name> trouvèrent l'inspiration pour écrire de belles histoires sur les mystères de l'univers. Leur amitié était comme les étoiles, brillante et éternelle.",
#   "first_names": ["Ava", "Noah"],
#   "last_names": ["Thompson", "Ramirez"],
#   "topics": ["l'écriture créative", "l'astronomie"],
#   "beginnings": ["Il y avait une fois une jeune fille passionnée d'écriture", "Au cœur de la nuit étoilée, une histoire extraordinaire commence"]
# }
# le texte est : Voici une histoire fascinante sur une jeune fille nommée Ava <first name>. Elle vivait dans une petite ville tranquille appelée Dupont-sur-Mer. Ava <first name> Thompson <last name> aimait passer son temps à lire des livres et à écrire des histoires. Elle rêvait de devenir écrivaine un jour. Un après-midi ensoleillé, Ava <first name> se promenait dans le parc quand elle rencontra un garçon curieux nommé Noah <first name>. Noah <first name> Ramirez <last name> était passionné par l'astronomie et adorait observer les étoiles. Ava <first name> et Noah <first name> se lièrent d'amitié instantanément et commencèrent à explorer leur passion commune pour les étoiles. Ils passaient des heures à observer le ciel nocturne et à discuter de l'univers infini. Grâce à leur amitié, Ava <first name> et Noah <first name> trouvèrent l'inspiration pour écrire de belles histoires sur les mystères de l'univers. Leur amitié était comme les étoiles, brillante et éternelle.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha', 'Léa', 'Nina', 'David', 'Olivia', 'Ava', 'Noah']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor', 'González', 'Taylor', 'Martin', 'Lefebvre', 'Garcia', 'Thompson', 'Ramirez']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages', "l'astronomie", 'la philosophie', 'la magie', "l'entrepreneuriat", 'les nouvelles technologies', "l'écriture créative", "l'astronomie"]
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Il était une fois un homme énigmatique nommé Luca <first name>.', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>.', 'Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine.', "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>.", "Il était une fois dans un monde connecté, une femme brillante du nom d'Olivia <first name>.", "Il y avait une fois une jeune fille passionnée d'écriture", 'Au cœur de la nuit étoilée, une histoire extraordinaire commence']
# réponse complète : {
#     "text": "Voici une histoire captivante sur une jeune femme nommée Aaliyah <first name>. Elle vivait dans une petite ville pittoresque appelée Bellecombe. Aaliyah <first name> Johnson <last name> était une artiste talentueuse et passionnée. Elle passait ses journées à créer de magnifiques peintures inspirées de la nature qui l'entourait. Un jour, alors qu'elle se promenait dans la forêt, Aaliyah <first name> rencontra un homme mystérieux nommé Diego <first name>. Il était un explorateur intrépide et avait parcouru le monde à la recherche d'aventures. Aaliyah <first name> était fascinée par les histoires de Diego <first name> et ils commencèrent à passer de nombreuses heures à discuter de leurs passions communes. Ils se soutenaient mutuellement dans leurs projets artistiques et leurs rêves les plus fous. Ensemble, Aaliyah <first name> et Diego <first name> créèrent une exposition d'art extraordinaire qui attira l'attention du monde entier. Leur collaboration artistique était magique et ils continuaient à explorer de nouvelles idées et à repousser les limites de leur créativité. Aaliyah <first name> et Diego <first name> étaient devenus des artistes renommés et vivaient une vie remplie de succès et de satisfaction.",
#     "first_names": ["Aaliyah", "Diego"],
#     "last_names": ["Johnson"],
#     "topics": ["l'art"],
#     "beginnings": ["Voici une histoire captivante sur une jeune femme nommée Aaliyah <first name>. Elle vivait dans une petite ville pittoresque appelée Bellecombe."]
# }
# le texte est : Voici une histoire captivante sur une jeune femme nommée Aaliyah <first name>. Elle vivait dans une petite ville pittoresque appelée Bellecombe. Aaliyah <first name> Johnson <last name> était une artiste talentueuse et passionnée. Elle passait ses journées à créer de magnifiques peintures inspirées de la nature qui l'entourait. Un jour, alors qu'elle se promenait dans la forêt, Aaliyah <first name> rencontra un homme mystérieux nommé Diego <first name>. Il était un explorateur intrépide et avait parcouru le monde à la recherche d'aventures. Aaliyah <first name> était fascinée par les histoires de Diego <first name> et ils commencèrent à passer de nombreuses heures à discuter de leurs passions communes. Ils se soutenaient mutuellement dans leurs projets artistiques et leurs rêves les plus fous. Ensemble, Aaliyah <first name> et Diego <first name> créèrent une exposition d'art extraordinaire qui attira l'attention du monde entier. Leur collaboration artistique était magique et ils continuaient à explorer de nouvelles idées et à repousser les limites de leur créativité. Aaliyah <first name> et Diego <first name> étaient devenus des artistes renommés et vivaient une vie remplie de succès et de satisfaction.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha', 'Léa', 'Nina', 'David', 'Olivia', 'Ava', 'Noah', 'Aaliyah', 'Diego']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor', 'González', 'Taylor', 'Martin', 'Lefebvre', 'Garcia', 'Thompson', 'Ramirez', 'Johnson']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages', "l'astronomie", 'la philosophie', 'la magie', "l'entrepreneuriat", 'les nouvelles technologies', "l'écriture créative", "l'astronomie", "l'art"]
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Il était une fois un homme énigmatique nommé Luca <first name>.', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>.', 'Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine.', "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>.", "Il était une fois dans un monde connecté, une femme brillante du nom d'Olivia <first name>.", "Il y avait une fois une jeune fille passionnée d'écriture", 'Au cœur de la nuit étoilée, une histoire extraordinaire commence', 'Voici une histoire captivante sur une jeune femme nommée Aaliyah <first name>. Elle vivait dans une petite ville pittoresque appelée Bellecombe.']
# réponse complète : {
#     "text": "Voici une histoire fascinante sur un jeune homme nommé Amir <first name>. Il vivait dans un petit village tranquille appelé Bellecombe. Amir <first name> Dubois <last name> aimait passer du temps dans la nature et découvrir de nouvelles cultures. Un jour, il rencontra une femme mystérieuse nommée Sofia <first name>. Ils étaient tous les deux passionnés par les voyages et la découverte de nouveaux horizons. Amir <first name> et Sofia <first name> partirent ensemble pour un voyage autour du monde. Ils visitèrent des pays exotiques et rencontrèrent des personnes fascinantes. Au fil de leurs aventures, Amir <first name> et Sofia <first name> développèrent une profonde amitié et une complicité sans égal. Chaque jour était une nouvelle aventure et chaque nuit était remplie d'étoiles étincelantes. Ensemble, ils apprirent à apprécier la beauté du monde et à vivre chaque instant avec passion. Amir <first name> et Sofia <first name> étaient inséparables et leur amitié dura toute leur vie.",
#     "first_names": ["Amir", "Sofia"],
#     "last_names": ["Dubois"],
#     "topics": ["les voyages"],
#     "beginnings": ["Voici une histoire fascinante sur un jeune homme nommé Amir <first name>. Il vivait dans un petit village tranquille appelé Bellecombe."]
# }
# le texte est : Voici une histoire fascinante sur un jeune homme nommé Amir <first name>. Il vivait dans un petit village tranquille appelé Bellecombe. Amir <first name> Dubois <last name> aimait passer du temps dans la nature et découvrir de nouvelles cultures. Un jour, il rencontra une femme mystérieuse nommée Sofia <first name>. Ils étaient tous les deux passionnés par les voyages et la découverte de nouveaux horizons. Amir <first name> et Sofia <first name> partirent ensemble pour un voyage autour du monde. Ils visitèrent des pays exotiques et rencontrèrent des personnes fascinantes. Au fil de leurs aventures, Amir <first name> et Sofia <first name> développèrent une profonde amitié et une complicité sans égal. Chaque jour était une nouvelle aventure et chaque nuit était remplie d'étoiles étincelantes. Ensemble, ils apprirent à apprécier la beauté du monde et à vivre chaque instant avec passion. Amir <first name> et Sofia <first name> étaient inséparables et leur amitié dura toute leur vie.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha', 'Léa', 'Nina', 'David', 'Olivia', 'Ava', 'Noah', 'Aaliyah', 'Diego', 'Amir', 'Sofia']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor', 'González', 'Taylor', 'Martin', 'Lefebvre', 'Garcia', 'Thompson', 'Ramirez', 'Johnson', 'Dubois']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages', "l'astronomie", 'la philosophie', 'la magie', "l'entrepreneuriat", 'les nouvelles technologies', "l'écriture créative", "l'astronomie", "l'art", 'les voyages']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Il était une fois un homme énigmatique nommé Luca <first name>.', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>.', 'Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine.', "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>.", "Il était une fois dans un monde connecté, une femme brillante du nom d'Olivia <first name>.", "Il y avait une fois une jeune fille passionnée d'écriture", 'Au cœur de la nuit étoilée, une histoire extraordinaire commence', 'Voici une histoire captivante sur une jeune femme nommée Aaliyah <first name>. Elle vivait dans une petite ville pittoresque appelée Bellecombe.', 'Voici une histoire fascinante sur un jeune homme nommé Amir <first name>. Il vivait dans un petit village tranquille appelé Bellecombe.']
# réponse complète : {
#     "text": "Voici une histoire incroyable sur une jeune femme nommée Anaïs <first name>. Elle vivait dans une petite ville tranquille appelée Châlons-sur-Marne. Anaïs <first name> Martinez <last name> était une artiste talentueuse, passionnée par la danse. Elle passait des heures à s'entraîner et à perfectionner ses mouvements gracieux. Un jour, Anaïs <first name> fut invitée à participer à un prestigieux concours de danse. C'était une occasion unique pour elle de montrer son talent et de réaliser son rêve de devenir danseuse professionnelle. Anaïs <first name> travailla dur et se prépara intensément pour la compétition. Le jour du concours, elle monta sur scène et dansa avec grâce et passion. Son talent et sa grâce éblouirent le public et les juges. À la fin de la soirée, Anaïs <first name> fut couronnée championne et réalisa enfin son rêve. Elle remercia sa famille et ses amis pour leur soutien inconditionnel tout au long de son parcours. Depuis lors, Anaïs <first name> est devenue une étoile montante dans le monde de la danse et inspire les autres par sa détermination et son talent exceptionnels.",
#     "first_names": ["Anaïs", "Liam", "Sofia", "Nina", "Raj", "Maxime", "Leyla", "Luca", "Aisha", "Aaliyah", "Diego", "Amir", "Olivia", "Ava", "Noah"],
#     "last_names": ["Martinez", "Smith", "Brown", "Johnson", "Garcia", "Thompson", "Ramirez", "Davis"],
#     "topics": ["l'art contemporain", "l'histoire de l'architecture", "la psychologie cognitive", "la gastronomie asiatique", "la philosophie stoïcienne", "la musique classique", "les randonnées en montagne", "la photographie de rue"],
#     "beginnings": ["Dans un petit village pittoresque", "Au cœur d'une ville animée", "Au sommet d'une montagne majestueuse", "Il y avait une fois", "Il y avait un garçon curieux", "Dans un petit village tranquille au cœur de la forêt, vivait un homme sage", "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux", "Il était une fois dans un monde connecté, une femme brillante"]
# }
# le texte est : Voici une histoire incroyable sur une jeune femme nommée Anaïs <first name>. Elle vivait dans une petite ville tranquille appelée Châlons-sur-Marne. Anaïs <first name> Martinez <last name> était une artiste talentueuse, passionnée par la danse. Elle passait des heures à s'entraîner et à perfectionner ses mouvements gracieux. Un jour, Anaïs <first name> fut invitée à participer à un prestigieux concours de danse. C'était une occasion unique pour elle de montrer son talent et de réaliser son rêve de devenir danseuse professionnelle. Anaïs <first name> travailla dur et se prépara intensément pour la compétition. Le jour du concours, elle monta sur scène et dansa avec grâce et passion. Son talent et sa grâce éblouirent le public et les juges. À la fin de la soirée, Anaïs <first name> fut couronnée championne et réalisa enfin son rêve. Elle remercia sa famille et ses amis pour leur soutien inconditionnel tout au long de son parcours. Depuis lors, Anaïs <first name> est devenue une étoile montante dans le monde de la danse et inspire les autres par sa détermination et son talent exceptionnels.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Julien', 'Maria', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha', 'Léa', 'Nina', 'David', 'Olivia', 'Ava', 'Noah', 'Aaliyah', 'Diego', 'Amir', 'Sofia', 'Anaïs', 'Liam', 'Sofia', 'Nina', 'Raj', 'Maxime', 'Leyla', 'Luca', 'Aisha', 'Aaliyah', 'Diego', 'Amir', 'Olivia', 'Ava', 'Noah']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Gonzalez', 'Taylor', 'Lopez', 'Cohen', 'González', 'Taylor', 'González', 'Taylor', 'Martin', 'Lefebvre', 'Garcia', 'Thompson', 'Ramirez', 'Johnson', 'Dubois', 'Martinez', 'Smith', 'Brown', 'Johnson', 'Garcia', 'Thompson', 'Ramirez', 'Davis']
# les sujets sont :
# ['la musique', 'la cuisine', 'les voyages', 'la littérature', 'le sport', 'les voyages', 'la culture indienne', 'les livres', 'les voyages', "l'astronomie", 'la philosophie', 'la magie', "l'entrepreneuriat", 'les nouvelles technologies', "l'écriture créative", "l'astronomie", "l'art", 'les voyages', "l'art contemporain", "l'histoire de l'architecture", 'la psychologie cognitive', 'la gastronomie asiatique', 'la philosophie stoïcienne', 'la musique classique', 'les randonnées en montagne', 'la photographie de rue']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', "Au cœur d'une ville animée", 'Dans un petit village pittoresque', "Au sommet d'une montagne majestueuse", 'Il était une fois', "Au cœur d'une ville animée", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Il était une fois un homme énigmatique nommé Luca <first name>.', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage appelé Luca <first name>.', 'Voici une histoire fascinante sur une jeune fille nommée Léa <first name>. Elle vivait dans une petite ville tranquille appelée Bellefontaine.', "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux appelé David <first name>.", "Il était une fois dans un monde connecté, une femme brillante du nom d'Olivia <first name>.", "Il y avait une fois une jeune fille passionnée d'écriture", 'Au cœur de la nuit étoilée, une histoire extraordinaire commence', 'Voici une histoire captivante sur une jeune femme nommée Aaliyah <first name>. Elle vivait dans une petite ville pittoresque appelée Bellecombe.', 'Voici une histoire fascinante sur un jeune homme nommé Amir <first name>. Il vivait dans un petit village tranquille appelé Bellecombe.', 'Dans un petit village pittoresque', "Au cœur d'une ville animée", "Au sommet d'une montagne majestueuse", 'Il y avait une fois', 'Il y avait un garçon curieux', 'Dans un petit village tranquille au cœur de la forêt, vivait un homme sage', "Dans une grande ville cosmopolite, vivait un homme d'affaires ambitieux", 'Il était une fois dans un monde connecté, une femme brillante']
#                                                 text
# 0  Voici un court texte sur une femme nommée Emma...
# 1  Voici une histoire fascinante sur une jeune fe...
# 2  Il y avait une fois un garçon curieux qui s'ap...
# 3  Il était une fois un homme énigmatique nommé L...
# 4  Voici une histoire fascinante sur une jeune fi...

# %%
df.head(10)
# Out:
#                                                 text
# 0  Voici un court texte sur une femme nommée Emma...
# 1  Voici une histoire fascinante sur une jeune fe...
# 2  Il y avait une fois un garçon curieux qui s'ap...
# 3  Il était une fois un homme énigmatique nommé L...
# 4  Voici une histoire fascinante sur une jeune fi...
# 5  Dans une grande ville cosmopolite, vivait un h...
# 6  Voici une histoire fascinante sur une jeune fi...
# 7  Voici une histoire captivante sur une jeune fe...
# 8  Voici une histoire fascinante sur un jeune hom...
# 9  Voici une histoire incroyable sur une jeune fe...
