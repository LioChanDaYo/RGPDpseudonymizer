# %%
import pandas as pd
# create an empty dataframe with only one column named "text"
df = pd.DataFrame(columns=["text"])

# %%
# make a function to read a string in a variable and concatenate it to the dataframe
def add_to_df(text):
    global df
    df = pd.concat([df, pd.DataFrame([text], columns=["text"])], ignore_index=True)

# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=1, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# # modèle de fonctionnement des prompts avec un texte
# text = f"""
# You should express what you want a model to do by \ 
# providing instructions that are as clear and \ 
# specific as you can possibly make them. \ 
# This will guide the model towards the desired output, \ 
# and reduce the chances of receiving irrelevant \ 
# or incorrect responses. Don't confuse writing a \ 
# clear prompt with writing a short prompt. \ 
# In many cases, longer prompts provide more clarity \ 
# and context for the model, which can lead to \ 
# more detailed and relevant outputs.
# """
# prompt = f"""
# Summarize the text delimited by triple backticks \ 
# into a single sentence.
# ```{text}```
# """
# response = get_completion(prompt)
# print(response)

# %%
# # text generation
# prompt = f"""
# Génère un court texte en Français. \
# Une fois le texte généré, recherche tous les prénoms, noms de famille et noms d'entreprises dans ce texte. \
# Ajoute la mention <first name> après chaque occurrence de chaque prénom ; ajoute la mention <last name> après chaque occurrence de chaque nom de famille ; ajoute la mention mention <company name> après chaque occurrence de chaque nom d'entreprise."
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to perform the actions described below:
# 1 - Generate a short text in French.
# 2 - Once generated, look for proper names.
# 3 - In the text from step 1, add the mention <first name> after each first name, add the mention <last name> after each last name.
# Here is an example of what the output should look like. Don't make your text about a similar topic or it will be rejected:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
# Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# add_to_df(response)
# df.head()

# %%
# # a function that make the prompt from two lists of first names and last names
# def makePrompt(first_names,last_names,topic,style,beginning):
#     prompt = f"""
#     Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
#     Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
#     ```
#     Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
#     ```
#     The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
#     the first names should be different from the following list: {first_names}
#     the last names should be different from the following list: {last_names}
#     the topic should be different from the following list: {topic}
#     the style should be different from the following list: {style}
#     the beginning should be different from the following list: {beginning}
#     Here are a few suggestions of topics: judiciaire, politique, sport, économie, santé, culture, technologie, environnement, éducation, société, international, sciences, médias, religion, faits divers, people, etc.
#     Here are few suggestions of styles: informatif, narratif, descriptif, argumentatif, explicatif, injonctif, poétique, humoristique, etc.
#     The output should be a JSON object with the following keys: text, first_names, last_names, topics, styles, beginnings.
#     """
#     return prompt

# %%
def makePrompt(first_names,last_names,topic,literary_genre,beginning):
    prompt = f"""
    Your task is to write a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
    the first names should be different from the following list: {first_names}
    the last names should be different from the following list: {last_names}
    the topic should be different from the following list: {topic}
    the literary genre should be different from the following list: {literary_genre}
    the beginning should be different from the following list: {beginning}
    Here is an example of what the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
    ```
    Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
    ```
    The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
    The output should be a JSON object with the following keys: text, first_names, last_names, topics, literary_genres, beginnings.
    """
    return prompt

# %%
import json
first_names = ["Pierre"]
last_names = ["Saint-Étienne"]
topic = []
literary_genre = []
beginning = ["Voici une histoire"]

# %%
# add texts in a loop to dataframe
for i in range(10):
    prompt = makePrompt(first_names,last_names,topic,literary_genre,beginning)
    response = get_completion(prompt)
    print(response)
    response = json.loads(response)
    text = response["text"]
    print(text)
    # get the contents of the "first_names" and "last_names" keys from the JSON object in the response and append them to the lists
    first_names = first_names + response["first_names"]
    last_names = last_names + response["last_names"]
    topic = topic + response["topics"]
    literary_genre = literary_genre + response["literary_genres"]
    beginning = beginning + response["beginnings"]
    print(first_names)
    print(last_names)
    print(topic)
    print(literary_genre)
    print(beginning)


    add_to_df(text)

df.head()
# Out:
# {
#     "text": "Une fois, dans une petite ville appelée Lyon, vivait une jeune fille nommée Emma <prénom>. Elle était passionnée par la musique et passait des heures à jouer du piano. Un jour, lors d'un concert de musique classique, Emma <prénom> rencontra un jeune homme talentueux du nom de Liam <prénom>. Ils partagèrent leur passion pour la musique et commencèrent à jouer ensemble. Liam <prénom> jouait de la guitare et Emma <prénom> du piano. Leur musique était magique et envoûtante. Ils se produisirent dans de nombreux concerts et devinrent célèbres dans le monde de la musique. Leur duo musical était unique et captivait le public à chaque représentation. Emma <prénom> et Liam <prénom> étaient inséparables sur scène et en dehors. Ils partageaient des moments de bonheur et de complicité. Leur musique était une véritable harmonie d'amour et de talent.",
#     "first_names": ["Emma", "Liam"],
#     "last_names": [],
#     "topics": ["Musique"],
#     "literary_genres": [],
#     "beginnings": []
# }
# Une fois, dans une petite ville appelée Lyon, vivait une jeune fille nommée Emma <prénom>. Elle était passionnée par la musique et passait des heures à jouer du piano. Un jour, lors d'un concert de musique classique, Emma <prénom> rencontra un jeune homme talentueux du nom de Liam <prénom>. Ils partagèrent leur passion pour la musique et commencèrent à jouer ensemble. Liam <prénom> jouait de la guitare et Emma <prénom> du piano. Leur musique était magique et envoûtante. Ils se produisirent dans de nombreux concerts et devinrent célèbres dans le monde de la musique. Leur duo musical était unique et captivait le public à chaque représentation. Emma <prénom> et Liam <prénom> étaient inséparables sur scène et en dehors. Ils partageaient des moments de bonheur et de complicité. Leur musique était une véritable harmonie d'amour et de talent.
# ['Pierre', 'Emma', 'Liam']
# ['Saint-Étienne']
# ['Musique']
# []
# ['Voici une histoire']
# {
#     "text": "Ils étaient deux jeunes étudiants passionnés par l'histoire, Julian <prénom> et Sofia <prénom>. Julian <prénom> était un brillant archéologue qui rêvait de découvrir des trésors enfouis depuis des siècles. Sofia <prénom>, quant à elle, était une érudite spécialisée dans l'histoire antique. Ensemble, ils formaient une équipe parfaite et étaient prêts à affronter toutes les aventures. Un jour, alors qu'ils travaillaient sur un projet de recherche, Julian <prénom> et Sofia <prénom> tombèrent sur un vieux parchemin mystérieux. Ce parchemin contenait des indices sur l'emplacement d'une cité perdue depuis des millénaires. Excités par cette découverte, ils décidèrent de partir à la recherche de cette cité légendaire. Leur voyage les conduisit à travers des paysages exotiques et des ruines antiques. Ils durent surmonter de nombreux obstacles et résoudre des énigmes complexes pour arriver enfin à la cité perdue. Là, ils découvrirent des trésors incroyables et firent des recherches qui réécrivaient l'histoire. Julian <prénom> et Sofia <prénom> étaient comblés et réalisèrent qu'ils étaient destinés à vivre toutes ces aventures ensemble.",
#     "first_names": ["Julian", "Sofia"],
#     "last_names": [],
#     "topics": ["Aventure", "Archéologie"],
#     "literary_genres": [],
#     "beginnings": []
# }
# Ils étaient deux jeunes étudiants passionnés par l'histoire, Julian <prénom> et Sofia <prénom>. Julian <prénom> était un brillant archéologue qui rêvait de découvrir des trésors enfouis depuis des siècles. Sofia <prénom>, quant à elle, était une érudite spécialisée dans l'histoire antique. Ensemble, ils formaient une équipe parfaite et étaient prêts à affronter toutes les aventures. Un jour, alors qu'ils travaillaient sur un projet de recherche, Julian <prénom> et Sofia <prénom> tombèrent sur un vieux parchemin mystérieux. Ce parchemin contenait des indices sur l'emplacement d'une cité perdue depuis des millénaires. Excités par cette découverte, ils décidèrent de partir à la recherche de cette cité légendaire. Leur voyage les conduisit à travers des paysages exotiques et des ruines antiques. Ils durent surmonter de nombreux obstacles et résoudre des énigmes complexes pour arriver enfin à la cité perdue. Là, ils découvrirent des trésors incroyables et firent des recherches qui réécrivaient l'histoire. Julian <prénom> et Sofia <prénom> étaient comblés et réalisèrent qu'ils étaient destinés à vivre toutes ces aventures ensemble.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia']
# ['Saint-Étienne']
# ['Musique', 'Aventure', 'Archéologie']
# []
# ['Voici une histoire']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>, passionnée par la photographie. Elle parcourait le monde à la recherche de paysages fascinants et de moments captivants à immortaliser. Un jour, lors d'un voyage en Inde, Emma <prénom> rencontra un homme mystérieux du nom de Ashwin <prénom>. Ashwin <prénom>, artiste talentueux, était connu pour ses peintures colorées et vibrantes. Les deux artistes tombèrent amoureux et commencèrent à collaborer sur des projets artistiques. Leur relation était une fusion de créativité et d'inspiration. Ensemble, ils créèrent des chefs-d'œuvre qui captivèrent le monde de l'art. Emma <prénom> et Ashwin <prénom> vécurent des aventures incroyables, explorant des lieux exotiques et partageant leur passion commune pour l'art. Leur amour était aussi beau et profond que leurs œuvres d'art. ",
#     "first_names": ["Emma", "Ashwin"],
#     "last_names": [],
#     "topics": ["Art"],
#     "literary_genres": [],
#     "beginnings": []
# }
# Il était une fois une jeune femme nommée Emma <prénom>, passionnée par la photographie. Elle parcourait le monde à la recherche de paysages fascinants et de moments captivants à immortaliser. Un jour, lors d'un voyage en Inde, Emma <prénom> rencontra un homme mystérieux du nom de Ashwin <prénom>. Ashwin <prénom>, artiste talentueux, était connu pour ses peintures colorées et vibrantes. Les deux artistes tombèrent amoureux et commencèrent à collaborer sur des projets artistiques. Leur relation était une fusion de créativité et d'inspiration. Ensemble, ils créèrent des chefs-d'œuvre qui captivèrent le monde de l'art. Emma <prénom> et Ashwin <prénom> vécurent des aventures incroyables, explorant des lieux exotiques et partageant leur passion commune pour l'art. Leur amour était aussi beau et profond que leurs œuvres d'art.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin']
# ['Saint-Étienne']
# ['Musique', 'Aventure', 'Archéologie', 'Art']
# []
# ['Voici une histoire']
# {
#     "text": "Voici une histoire émouvante sur une jeune femme appelée Emma <prénom>. Elle était passionnée par la cuisine et rêvait de devenir une chef renommée. Emma <prénom> passait des heures à expérimenter de nouvelles recettes et à améliorer ses compétences culinaires. Un jour, elle découvrit un concours de cuisine dans sa ville natale. Déterminée à montrer son talent, Emma <prénom> décida de participer. Elle créa un plat unique qui mélangeait des saveurs exotiques et des techniques de cuisine innovantes. Lors du concours, Emma <prénom> était nerveuse mais concentrée. Elle présenta son plat devant un panel de juges célèbres. À sa grande joie, son plat fut acclamé et Emma <prénom> remporta le premier prix du concours. Sa victoire lui ouvrit les portes de la renommée et elle fut invitée à travailler dans de prestigieux restaurants. Emma <prénom> réalisa finalement son rêve et devint une chef respectée dans le monde de la gastronomie.",
#     "first_names": ["Emma"],
#     "last_names": [],
#     "topics": ["Cuisine"],
#     "literary_genres": [],
#     "beginnings": []
# }
# Voici une histoire émouvante sur une jeune femme appelée Emma <prénom>. Elle était passionnée par la cuisine et rêvait de devenir une chef renommée. Emma <prénom> passait des heures à expérimenter de nouvelles recettes et à améliorer ses compétences culinaires. Un jour, elle découvrit un concours de cuisine dans sa ville natale. Déterminée à montrer son talent, Emma <prénom> décida de participer. Elle créa un plat unique qui mélangeait des saveurs exotiques et des techniques de cuisine innovantes. Lors du concours, Emma <prénom> était nerveuse mais concentrée. Elle présenta son plat devant un panel de juges célèbres. À sa grande joie, son plat fut acclamé et Emma <prénom> remporta le premier prix du concours. Sa victoire lui ouvrit les portes de la renommée et elle fut invitée à travailler dans de prestigieux restaurants. Emma <prénom> réalisa finalement son rêve et devint une chef respectée dans le monde de la gastronomie.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin', 'Emma']
# ['Saint-Étienne']
# ['Musique', 'Aventure', 'Archéologie', 'Art', 'Cuisine']
# []
# ['Voici une histoire']
# {
#     "text": "Il était une fois une jeune fille nommée Emma <prénom>. Elle vivait dans une petite ville du sud de la France appelée Nice <nom de famille>. Emma <prénom> était une passionnée de voyage et d'aventure. Elle rêvait de parcourir le monde et de découvrir de nouveaux horizons. Un jour, elle décida de partir en voyage en Asie <topic>. Son premier arrêt était le Japon, un pays fascinant riche en histoire et en tradition. Emma <prénom> passait ses journées à explorer les temples anciens, à déguster la délicieuse cuisine locale et à admirer les magnifiques jardins japonais. Elle fit également la rencontre de Kenji <prénom>, un sympathique guide touristique qui était passionné par la culture japonaise. Emma <prénom> et Kenji <prénom> devinrent rapidement amis et partagèrent de nombreuses aventures ensemble. De temples en temples, de villes en villes, ils découvrirent les merveilles du Japon. Finalement, le voyage toucha à sa fin et Emma <prénom> dut rentrer chez elle. Mais les souvenirs de son expérience au Japon resteront à jamais gravés dans son cœur.",
#     "first_names": ["Emma", "Kenji"],
#     "last_names": ["Nice"],
#     "topics": ["Asie"],
#     "literary_genres": ["Voyage"],
#     "beginnings": []
# }
# Il était une fois une jeune fille nommée Emma <prénom>. Elle vivait dans une petite ville du sud de la France appelée Nice <nom de famille>. Emma <prénom> était une passionnée de voyage et d'aventure. Elle rêvait de parcourir le monde et de découvrir de nouveaux horizons. Un jour, elle décida de partir en voyage en Asie <topic>. Son premier arrêt était le Japon, un pays fascinant riche en histoire et en tradition. Emma <prénom> passait ses journées à explorer les temples anciens, à déguster la délicieuse cuisine locale et à admirer les magnifiques jardins japonais. Elle fit également la rencontre de Kenji <prénom>, un sympathique guide touristique qui était passionné par la culture japonaise. Emma <prénom> et Kenji <prénom> devinrent rapidement amis et partagèrent de nombreuses aventures ensemble. De temples en temples, de villes en villes, ils découvrirent les merveilles du Japon. Finalement, le voyage toucha à sa fin et Emma <prénom> dut rentrer chez elle. Mais les souvenirs de son expérience au Japon resteront à jamais gravés dans son cœur.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin', 'Emma', 'Emma', 'Kenji']
# ['Saint-Étienne', 'Nice']
# ['Musique', 'Aventure', 'Archéologie', 'Art', 'Cuisine', 'Asie']
# ['Voyage']
# ['Voici une histoire']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <first name> qui vivait dans la belle ville de Nice <last name>. Emma <first name> avait une passion pour la science et rêvait de devenir une grande chercheuse. Elle passait la plupart de son temps libre à lire des livres sur la biologie et à explorer la nature environnante. Un jour, Emma <first name> découvrit une plante exotique rare qu'elle n'avait jamais vue auparavant. Intriguée, elle décida de mener des recherches approfondies sur cette plante. Au fil de ses investigations, Emma <first name> fit une découverte extraordinaire : cette plante avait des propriétés médicinales étonnantes. Elle réalisa que cette plante pouvait potentiellement changer la vie de nombreuses personnes malades. Emma <first name> travailla sans relâche pour développer un traitement à base de cette plante miracle. Après de nombreux essais et erreurs, elle réussit finalement à mettre au point un médicament révolutionnaire. Grâce à son travail acharné, Emma <first name> sauva des vies et devint une chercheuse renommée dans le monde entier.",
#     "first_names": ["Emma"],
#     "last_names": ["Nice"],
#     "topics": ["Science"],
#     "literary_genres": ["Scientifique"],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <first name> qui vivait dans la belle ville de Nice <last name>. Emma <first name> avait une passion pour la science et rêvait de devenir une grande chercheuse. Elle passait la plupart de son temps libre à lire des livres sur la biologie et à explorer la nature environnante. Un jour, Emma <first name> découvrit une plante exotique rare qu'elle n'avait jamais vue auparavant. Intriguée, elle décida de mener des recherches approfondies sur cette plante. Au fil de ses investigations, Emma <first name> fit une découverte extraordinaire : cette plante avait des propriétés médicinales étonnantes. Elle réalisa que cette plante pouvait potentiellement changer la vie de nombreuses personnes malades. Emma <first name> travailla sans relâche pour développer un traitement à base de cette plante miracle. Après de nombreux essais et erreurs, elle réussit finalement à mettre au point un médicament révolutionnaire. Grâce à son travail acharné, Emma <first name> sauva des vies et devint une chercheuse renommée dans le monde entier.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin', 'Emma', 'Emma', 'Kenji', 'Emma']
# ['Saint-Étienne', 'Nice', 'Nice']
# ['Musique', 'Aventure', 'Archéologie', 'Art', 'Cuisine', 'Asie', 'Science']
# ['Voyage', 'Scientifique']
# ['Voici une histoire', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune fille nommée Emma <prenom> qui vivait dans un petit village près de la mer. Emma <prenom> était passionnée par la danse depuis son plus jeune âge. Chaque jour, elle s'entraînait dur pour devenir la meilleure danseuse de son école. Son talent et sa grâce étaient admirés par tout le monde. Un jour, Emma <prenom> reçut une invitation spéciale pour participer à une compétition de danse internationale. C'était une occasion unique pour elle de montrer son talent et de représenter son pays. Emma <prenom> travailla encore plus dur pour se préparer à cette compétition. Elle pratiquait des heures chaque jour et se donnait à fond pour être parfaite. Le jour de la compétition, Emma <prenom> monta sur scène avec confiance. Elle dansa avec grâce et émotion, captivant tous les spectateurs. À la fin de sa performance, le public se leva en applaudissant et Emma <prenom> reçut une standing ovation. Elle remporta la première place et devint une véritable star de la danse. Depuis ce jour, Emma <prenom> continua de briller sur les scènes du monde entier, réalisant son rêve de devenir une danseuse renommée.",
#     "first_names": ["Emma"],
#     "last_names": [],
#     "topics": ["Danse"],
#     "literary_genres": [],
#     "beginnings": []
# }
# Il était une fois une jeune fille nommée Emma <prenom> qui vivait dans un petit village près de la mer. Emma <prenom> était passionnée par la danse depuis son plus jeune âge. Chaque jour, elle s'entraînait dur pour devenir la meilleure danseuse de son école. Son talent et sa grâce étaient admirés par tout le monde. Un jour, Emma <prenom> reçut une invitation spéciale pour participer à une compétition de danse internationale. C'était une occasion unique pour elle de montrer son talent et de représenter son pays. Emma <prenom> travailla encore plus dur pour se préparer à cette compétition. Elle pratiquait des heures chaque jour et se donnait à fond pour être parfaite. Le jour de la compétition, Emma <prenom> monta sur scène avec confiance. Elle dansa avec grâce et émotion, captivant tous les spectateurs. À la fin de sa performance, le public se leva en applaudissant et Emma <prenom> reçut une standing ovation. Elle remporta la première place et devint une véritable star de la danse. Depuis ce jour, Emma <prenom> continua de briller sur les scènes du monde entier, réalisant son rêve de devenir une danseuse renommée.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin', 'Emma', 'Emma', 'Kenji', 'Emma', 'Emma']
# ['Saint-Étienne', 'Nice', 'Nice']
# ['Musique', 'Aventure', 'Archéologie', 'Art', 'Cuisine', 'Asie', 'Science', 'Danse']
# ['Voyage', 'Scientifique']
# ['Voici une histoire', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la philosophie <prénom> et passait ses journées à lire des livres et à réfléchir sur la vie. Emma <prénom> avait un nom de famille unique: Dupont <nom de famille>. Elle aimait explorer les concepts de la réalité et de la perception à travers ses écrits et ses discussions avec ses amis. Un jour, Emma <prénom> rencontra un jeune homme nommé Liam <prénom> lors d'une conférence sur la philosophie. Ils découvrirent rapidement qu'ils partageaient la même passion pour la pensée critique et la recherche de la vérité. Ensemble, ils formèrent un groupe d'étude philosophique et commencèrent à organiser des débats et des présentations pour partager leurs idées avec les autres. Leur groupe devint rapidement populaire dans la communauté et attira l'attention de nombreux philosophes renommés. Emma <prénom> et Liam <prénom> étaient ravis de l'impact positif qu'ils avaient sur les autres et étaient déterminés à continuer à promouvoir la pensée philosophique. Leur voyage intellectuel les emmena dans des lieux fascinants et les fit rencontrer des penseurs influents du monde entier. Ensemble, ils espéraient changer le monde grâce à leur passion commune pour la philosophie.",
#     "first_names": ["Emma", "Liam"],
#     "last_names": ["Dupont"],
#     "topics": ["Philosophie"],
#     "literary_genres": ["Philosophique"],
#     "beginnings": ["Il y avait une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la philosophie <prénom> et passait ses journées à lire des livres et à réfléchir sur la vie. Emma <prénom> avait un nom de famille unique: Dupont <nom de famille>. Elle aimait explorer les concepts de la réalité et de la perception à travers ses écrits et ses discussions avec ses amis. Un jour, Emma <prénom> rencontra un jeune homme nommé Liam <prénom> lors d'une conférence sur la philosophie. Ils découvrirent rapidement qu'ils partageaient la même passion pour la pensée critique et la recherche de la vérité. Ensemble, ils formèrent un groupe d'étude philosophique et commencèrent à organiser des débats et des présentations pour partager leurs idées avec les autres. Leur groupe devint rapidement populaire dans la communauté et attira l'attention de nombreux philosophes renommés. Emma <prénom> et Liam <prénom> étaient ravis de l'impact positif qu'ils avaient sur les autres et étaient déterminés à continuer à promouvoir la pensée philosophique. Leur voyage intellectuel les emmena dans des lieux fascinants et les fit rencontrer des penseurs influents du monde entier. Ensemble, ils espéraient changer le monde grâce à leur passion commune pour la philosophie.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin', 'Emma', 'Emma', 'Kenji', 'Emma', 'Emma', 'Emma', 'Liam']
# ['Saint-Étienne', 'Nice', 'Nice', 'Dupont']
# ['Musique', 'Aventure', 'Archéologie', 'Art', 'Cuisine', 'Asie', 'Science', 'Danse', 'Philosophie']
# ['Voyage', 'Scientifique', 'Philosophique']
# ['Voici une histoire', 'Il était une fois', 'Il y avait une fois']
# {
#   "text": "C'était une belle journée ensoleillée lorsque Julien <prénom> et Emma <prénom> se sont rencontrés pour la première fois. Ils étaient tous les deux passionnés de musique <topic> et se sont rapidement liés d'amitié. Julien <prénom> était un talentueux guitariste et Emma <prénom> avait une voix enchanteresse. Ensemble, ils ont formé un groupe de musique <literary_genre> et ont commencé à écrire leurs propres chansons. Leurs mélodies étaient empreintes de mélancolie et leurs paroles racontaient des histoires d'amour et de perte. Le groupe a rapidement gagné en popularité et a commencé à se produire dans des bars locaux. Leurs performances captivaient le public et leur musique <topic> était appréciée de tous. Malgré leur succès, Julien <prénom> et Emma <prénom> sont restés modestes et dévoués à leur art. Ils savaient que la musique <topic> était leur véritable passion et ils étaient prêts à travailler dur pour atteindre leurs rêves. Grâce à leur talent et à leur détermination, Julien <prénom> et Emma <prénom> sont devenus des artistes accomplis et ont connu un succès international. Leur musique <topic> continue d'inspirer les gens du monde entier et de toucher les cœurs avec ses mélodies intemporelles. Ils sont devenus des icônes de la musique <topic> et leur héritage perdure encore aujourd'hui.",
#   "first_names": ["Julien", "Emma"],
#   "last_names": ["Dubois", "Garcia"],
#   "topics": ["Musique"],
#   "literary_genres": ["Romantique"],
#   "beginnings": ["Il était une fois"]
# }
# C'était une belle journée ensoleillée lorsque Julien <prénom> et Emma <prénom> se sont rencontrés pour la première fois. Ils étaient tous les deux passionnés de musique <topic> et se sont rapidement liés d'amitié. Julien <prénom> était un talentueux guitariste et Emma <prénom> avait une voix enchanteresse. Ensemble, ils ont formé un groupe de musique <literary_genre> et ont commencé à écrire leurs propres chansons. Leurs mélodies étaient empreintes de mélancolie et leurs paroles racontaient des histoires d'amour et de perte. Le groupe a rapidement gagné en popularité et a commencé à se produire dans des bars locaux. Leurs performances captivaient le public et leur musique <topic> était appréciée de tous. Malgré leur succès, Julien <prénom> et Emma <prénom> sont restés modestes et dévoués à leur art. Ils savaient que la musique <topic> était leur véritable passion et ils étaient prêts à travailler dur pour atteindre leurs rêves. Grâce à leur talent et à leur détermination, Julien <prénom> et Emma <prénom> sont devenus des artistes accomplis et ont connu un succès international. Leur musique <topic> continue d'inspirer les gens du monde entier et de toucher les cœurs avec ses mélodies intemporelles. Ils sont devenus des icônes de la musique <topic> et leur héritage perdure encore aujourd'hui.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin', 'Emma', 'Emma', 'Kenji', 'Emma', 'Emma', 'Emma', 'Liam', 'Julien', 'Emma']
# ['Saint-Étienne', 'Nice', 'Nice', 'Dupont', 'Dubois', 'Garcia']
# ['Musique', 'Aventure', 'Archéologie', 'Art', 'Cuisine', 'Asie', 'Science', 'Danse', 'Philosophie', 'Musique']
# ['Voyage', 'Scientifique', 'Philosophique', 'Romantique']
# ['Voici une histoire', 'Il était une fois', 'Il y avait une fois', 'Il était une fois']
# {
#   "text": "Il y avait une fois une fille courageuse nommée Emma <prénom>. Elle vivait dans un petit village appelé Nice <nom de famille>. Emma <prénom> aimait découvrir de nouveaux endroits et apprendre de nouvelles choses. Un jour, elle décida de partir à l'aventure en solo. Elle parcourut de vastes manoirs et rencontra des personnes fascinantes tout au long de son voyage. Emma <prénom> adorait écouter les histoires des habitants locaux et découvrir les secrets cachés de chaque endroit qu'elle visitait.\n\nUn jour, Emma <prénom> fit une rencontre inattendue. Elle rencontra un archéologue accompli nommé Julian <prénom>. Julian <prénom> était passionné par l'archéologie et passait la plupart de son temps à explorer d'anciennes ruines et des sites historiques. Emma <prénom> et Julian <prénom> découvrirent rapidement qu'ils avaient une passion commune pour l'histoire et les civilisations antiques.\n\nIls décidèrent donc de faire équipe et de partir ensemble à la recherche d'un trésor perdu depuis des siècles. Leur aventure les emmena dans des contrées lointaines et remplis de danger. Ils surmontèrent des épreuves difficiles, mais leur détermination ne faiblit jamais.\n\nFinalement, après de nombreux mois de recherche épuisante, Emma <prénom> et Julian <prénom> trouvèrent enfin le trésor tant convoité. Leur découverte était d'une valeur inestimable et allait changer à jamais notre compréhension de l'histoire.\n\nEmma <prénom> et Julian <prénom> devinrent célèbres pour leur incroyable exploit et continuèrent à explorer le monde ensemble. Leur histoire était une source d'inspiration pour de nombreux aventuriers et archéologues en herbe.\n\nAinsi se termine l'histoire de Emma <prénom> et Julian <prénom>, deux âmes passionnées qui découvrirent le monde en quête de trésors perdus.",
#   "first_names": ["Emma", "Julian"],
#   "last_names": ["Nice", "Saint-Étienne"],
#   "topics": ["Aventure", "Archéologie"],
#   "literary_genres": ["Suspense", "Historique"],
#   "beginnings": ["Il y avait une fois", "Dans un royaume lointain"]
# }
# Il y avait une fois une fille courageuse nommée Emma <prénom>. Elle vivait dans un petit village appelé Nice <nom de famille>. Emma <prénom> aimait découvrir de nouveaux endroits et apprendre de nouvelles choses. Un jour, elle décida de partir à l'aventure en solo. Elle parcourut de vastes manoirs et rencontra des personnes fascinantes tout au long de son voyage. Emma <prénom> adorait écouter les histoires des habitants locaux et découvrir les secrets cachés de chaque endroit qu'elle visitait.
#
# Un jour, Emma <prénom> fit une rencontre inattendue. Elle rencontra un archéologue accompli nommé Julian <prénom>. Julian <prénom> était passionné par l'archéologie et passait la plupart de son temps à explorer d'anciennes ruines et des sites historiques. Emma <prénom> et Julian <prénom> découvrirent rapidement qu'ils avaient une passion commune pour l'histoire et les civilisations antiques.
#
# Ils décidèrent donc de faire équipe et de partir ensemble à la recherche d'un trésor perdu depuis des siècles. Leur aventure les emmena dans des contrées lointaines et remplis de danger. Ils surmontèrent des épreuves difficiles, mais leur détermination ne faiblit jamais.
#
# Finalement, après de nombreux mois de recherche épuisante, Emma <prénom> et Julian <prénom> trouvèrent enfin le trésor tant convoité. Leur découverte était d'une valeur inestimable et allait changer à jamais notre compréhension de l'histoire.
#
# Emma <prénom> et Julian <prénom> devinrent célèbres pour leur incroyable exploit et continuèrent à explorer le monde ensemble. Leur histoire était une source d'inspiration pour de nombreux aventuriers et archéologues en herbe.
#
# Ainsi se termine l'histoire de Emma <prénom> et Julian <prénom>, deux âmes passionnées qui découvrirent le monde en quête de trésors perdus.
# ['Pierre', 'Emma', 'Liam', 'Julian', 'Sofia', 'Emma', 'Ashwin', 'Emma', 'Emma', 'Kenji', 'Emma', 'Emma', 'Emma', 'Liam', 'Julien', 'Emma', 'Emma', 'Julian']
# ['Saint-Étienne', 'Nice', 'Nice', 'Dupont', 'Dubois', 'Garcia', 'Nice', 'Saint-Étienne']
# ['Musique', 'Aventure', 'Archéologie', 'Art', 'Cuisine', 'Asie', 'Science', 'Danse', 'Philosophie', 'Musique', 'Aventure', 'Archéologie']
# ['Voyage', 'Scientifique', 'Philosophique', 'Romantique', 'Suspense', 'Historique']
# ['Voici une histoire', 'Il était une fois', 'Il y avait une fois', 'Il était une fois', 'Il y avait une fois', 'Dans un royaume lointain']
#                                                 text
# 0  Une fois, dans une petite ville appelée Lyon, ...
# 1  Ils étaient deux jeunes étudiants passionnés p...
# 2  Il était une fois une jeune femme nommée Emma ...
# 3  Voici une histoire émouvante sur une jeune fem...
# 4  Il était une fois une jeune fille nommée Emma ...

# %%
df.head(10)
# Out:
#                                                 text
# 0  Une fois, dans une petite ville appelée Lyon, ...
# 1  Ils étaient deux jeunes étudiants passionnés p...
# 2  Il était une fois une jeune femme nommée Emma ...
# 3  Voici une histoire émouvante sur une jeune fem...
# 4  Il était une fois une jeune fille nommée Emma ...
# 5  Il était une fois une jeune femme nommée Emma ...
# 6  Il était une fois une jeune fille nommée Emma ...
# 7  Il était une fois une jeune femme nommée Emma ...
# 8  C'était une belle journée ensoleillée lorsque ...
# 9  Il y avait une fois une fille courageuse nommé...
