# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# modèle de fonctionnement des prompts avec un texte
text = f"""
You should express what you want a model to do by \ 
providing instructions that are as clear and \ 
specific as you can possibly make them. \ 
This will guide the model towards the desired output, \ 
and reduce the chances of receiving irrelevant \ 
or incorrect responses. Don't confuse writing a \ 
clear prompt with writing a short prompt. \ 
In many cases, longer prompts provide more clarity \ 
and context for the model, which can lead to \ 
more detailed and relevant outputs.
"""
prompt = f"""
Summarize the text delimited by triple backticks \ 
into a single sentence.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# To guide a model towards the desired output and reduce irrelevant or incorrect responses, it is important to provide clear and specific instructions, which can be achieved through longer prompts that offer more clarity and context.

# %%
# text generation
prompt = "Generate a short text in French. \
Once generated, look for proper names and company names in it. \
Add the mention {first name} after each first name, add the mention {last name} after each last name, and add the mention {company name} after each company name."
response = get_completion(prompt)
print(response)
# Out:
# J'ai récemment visité Paris, la magnifique capitale de la France. J'ai adoré me promener le long de la Seine et admirer la Tour Eiffel scintillante la nuit. J'ai également visité le musée du Louvre, où j'ai pu contempler la célèbre Joconde de Léonard de Vinci.
#
# Pendant mon séjour, j'ai rencontré Marie Dupont, une amie d'enfance. Nous avons déjeuné dans un charmant café appelé Le Petit Bistro. Marie travaille pour la société XYZ, une entreprise spécialisée dans les nouvelles technologies.
#
# Ensuite, j'ai assisté à une conférence sur l'intelligence artificielle donnée par le professeur Jean-Luc Martin. Il est un expert renommé dans le domaine et travaille pour la société ABC, une entreprise de recherche en technologie de pointe.
#
# Après la conférence, j'ai fait la connaissance de Pierre Lefèvre, un entrepreneur passionné par l'innovation. Il est le fondateur de la société Innovatech, une start-up prometteuse dans le domaine de la réalité virtuelle.
#
# En conclusion, mon voyage à Paris a été enrichissant et m'a permis de rencontrer des personnes intéressantes telles que Marie Dupont, le professeur Jean-Luc Martin et Pierre Lefèvre. J'ai également découvert des entreprises dynamiques comme XYZ, ABC et Innovatech.

# %%
# text generation
prompt = "Génère un court texte en Français. \
Une fois le texte généré, recherche tous les prénoms, noms de famille et noms d'entreprises dans ce texte. \
Ajoute la mention <first name> après chaque occurrence de chaque prénom ; ajoute la mention <last name> après chaque occurrence de chaque nom de famille ; ajoute la mention mention <company name> après chaque occurrence de chaque nom d'entreprise."
response = get_completion(prompt)
print(response)
# Out:
# Il était une fois, dans la petite ville de Sainte-Marie, un jeune homme nommé Pierre. Pierre était un étudiant brillant et ambitieux, toujours prêt à relever de nouveaux défis. Il rêvait de devenir un grand entrepreneur et de fonder sa propre entreprise. Un jour, il rencontra une femme charmante du nom de Sophie. Sophie était une artiste talentueuse et passionnée par son métier. Pierre et Sophie tombèrent amoureux et décidèrent de créer ensemble une entreprise qui allierait leurs compétences et leurs passions. Ils baptisèrent leur entreprise "CréaArt", un nom qui reflétait parfaitement leur vision artistique et leur esprit entrepreneurial. Pierre et Sophie travaillèrent dur pour faire de CréaArt un succès. Ils firent appel à leur ami d'enfance, Thomas, un expert en marketing, pour les aider à promouvoir leur entreprise. Grâce à leur dévouement et à leur talent, CréaArt devint rapidement une référence dans le domaine de l'art et du design. Les clients affluaient et les projets se multipliaient. Pierre, Sophie et Thomas étaient fiers de leur réussite et de l'impact positif qu'ils avaient sur la communauté artistique. Ils continuèrent à innover et à repousser les limites de la créativité, toujours animés par leur passion commune. Pierre, Sophie et Thomas étaient devenus des figures respectées dans le monde de l'entrepreneuriat et de l'art. Leur entreprise, CréaArt, était devenue un symbole de réussite et d'inspiration pour de nombreux jeunes entrepreneurs. Ils étaient convaincus que leur aventure ne faisait que commencer et qu'ils avaient encore de nombreuses idées à concrétiser. Ils étaient prêts à relever tous les défis qui se présenteraient à eux, avec détermination et enthousiasme. <first name> Pierre <last name> Sophie <first name> Thomas <company name> CréaArt.
