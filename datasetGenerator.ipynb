# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# modèle de fonctionnement des prompts avec un texte
text = f"""
You should express what you want a model to do by \ 
providing instructions that are as clear and \ 
specific as you can possibly make them. \ 
This will guide the model towards the desired output, \ 
and reduce the chances of receiving irrelevant \ 
or incorrect responses. Don't confuse writing a \ 
clear prompt with writing a short prompt. \ 
In many cases, longer prompts provide more clarity \ 
and context for the model, which can lead to \ 
more detailed and relevant outputs.
"""
prompt = f"""
Summarize the text delimited by triple backticks \ 
into a single sentence.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# To guide a model towards the desired output and reduce irrelevant or incorrect responses, it is important to provide clear and specific instructions, which can be achieved through longer prompts that offer more clarity and context.

# %%
# text generation
prompt = "Generate a short text in French. \
Once generated, look for proper names and company names in it. \
Add the mention {first name} after each first name, add the mention {last name} after each last name, and add the mention {company name} after each company name."
response = get_completion(prompt)
print(response)
# Out:
# J'ai récemment visité Paris, la magnifique capitale de la France. J'ai adoré me promener le long de la Seine et admirer la Tour Eiffel scintillante la nuit. J'ai également visité le musée du Louvre, où j'ai pu contempler la célèbre Joconde de Léonard de Vinci.
#
# Pendant mon séjour, j'ai rencontré Marie Dupont, une amie d'enfance que je n'avais pas vue depuis des années. Nous avons déjeuné dans un charmant café appelé Le Petit Bistro. Marie travaille maintenant pour une grande entreprise de cosmétiques appelée Beauté Éternelle.
#
# En me promenant dans les rues animées de Paris, j'ai remarqué une boutique de mode très chic appelée La Mode Parisienne. J'ai également visité la célèbre pâtisserie Pierre Gagnaire, où j'ai dégusté les délicieuses pâtisseries de renommée mondiale.
#
# Paris est vraiment une ville incroyable, regorgeant de culture, d'histoire et de beauté. J'ai hâte d'y retourner et d'explorer davantage ses merveilles.

# %%
# text generation
prompt = "Génère un court texte en Français. \
Une fois le texte généré, recherche chaque occurence de noms propres, y compris les noms d'entreprises. \
Ajoute la mention {first name} après chaque prénom ; ajoute la mention {last name} après chaque nom de famille ; ajoute la mention mention {company name} après chaque nom d'entreprise."
response = get_completion(prompt)
print(response)
# Out:
# Il était une fois, dans la charmante ville de Paris, une jeune femme prénommée Marie {first name}. Elle était passionnée par l'art et travaillait comme guide touristique pour la célèbre entreprise de visites guidées "Paris Tours {company name}". Marie était connue pour sa grande connaissance de l'histoire de la ville et sa capacité à captiver son public.
#
# Un jour, lors d'une visite au musée du Louvre, Marie rencontra un homme mystérieux nommé Jean Dupont {first name} {last name}. Jean était un collectionneur d'art renommé et propriétaire de la galerie d'art "Dupont Art {company name}". Il était fasciné par les talents de Marie et lui proposa de collaborer sur une exposition d'art contemporain.
#
# Marie accepta avec enthousiasme cette opportunité et commença à travailler avec Jean sur la sélection des artistes et la mise en place de l'exposition. Ils passèrent des heures à discuter de leur passion commune pour l'art et à planifier chaque détail de l'événement.
#
# L'exposition fut un véritable succès et attira de nombreux amateurs d'art du monde entier. Marie et Jean furent félicités pour leur travail exceptionnel et leur vision artistique. Leur collaboration fut si fructueuse qu'ils décidèrent de créer leur propre entreprise d'organisation d'événements artistiques, baptisée "Artistic Events {company name}".
#
# Ainsi, Marie et Jean continuèrent à travailler ensemble, alliant leurs talents et leur passion pour l'art. Leur entreprise prospéra et devint rapidement une référence dans le domaine de l'organisation d'événements artistiques à Paris.
#
# Marie {first name}, Jean Dupont {first name} {last name} et leur entreprise "Artistic Events {company name}" laissèrent une empreinte indélébile dans le monde de l'art à Paris, en créant des expériences uniques et en mettant en valeur le talent des artistes contemporains.
