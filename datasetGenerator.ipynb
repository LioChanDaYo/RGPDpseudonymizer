# %%
import pandas as pd
# create an empty dataframe with only one column named "text"
df = pd.DataFrame(columns=["text"])

# %%
# make a function to read a string in a variable and concatenate it to the dataframe
def add_to_df(text):
    global df
    df = pd.concat([df, pd.DataFrame([text], columns=["text"])], ignore_index=True)

# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# # modèle de fonctionnement des prompts avec un texte
# text = f"""
# You should express what you want a model to do by \ 
# providing instructions that are as clear and \ 
# specific as you can possibly make them. \ 
# This will guide the model towards the desired output, \ 
# and reduce the chances of receiving irrelevant \ 
# or incorrect responses. Don't confuse writing a \ 
# clear prompt with writing a short prompt. \ 
# In many cases, longer prompts provide more clarity \ 
# and context for the model, which can lead to \ 
# more detailed and relevant outputs.
# """
# prompt = f"""
# Summarize the text delimited by triple backticks \ 
# into a single sentence.
# ```{text}```
# """
# response = get_completion(prompt)
# print(response)

# %%
# # text generation
# prompt = f"""
# Génère un court texte en Français. \
# Une fois le texte généré, recherche tous les prénoms, noms de famille et noms d'entreprises dans ce texte. \
# Ajoute la mention <first name> après chaque occurrence de chaque prénom ; ajoute la mention <last name> après chaque occurrence de chaque nom de famille ; ajoute la mention mention <company name> après chaque occurrence de chaque nom d'entreprise."
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to perform the actions described below:
# 1 - Generate a short text in French.
# 2 - Once generated, look for proper names.
# 3 - In the text from step 1, add the mention <first name> after each first name, add the mention <last name> after each last name.
# Here is an example of what the output should look like. Don't make your text about a similar topic or it will be rejected:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
# Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# add_to_df(response)
# df.head()

# %%
# # a function that make the prompt from two lists of first names and last names
# def makePrompt(first_names,last_names,topic,style,beginning):
#     prompt = f"""
#     Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
#     Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
#     ```
#     Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
#     ```
#     The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
#     the first names should be different from the following list: {first_names}
#     the last names should be different from the following list: {last_names}
#     the topic should be different from the following list: {topic}
#     the style should be different from the following list: {style}
#     the beginning should be different from the following list: {beginning}
#     Here are a few suggestions of topics: judiciaire, politique, sport, économie, santé, culture, technologie, environnement, éducation, société, international, sciences, médias, religion, faits divers, people, etc.
#     Here are few suggestions of styles: informatif, narratif, descriptif, argumentatif, explicatif, injonctif, poétique, humoristique, etc.
#     The output should be a JSON object with the following keys: text, first_names, last_names, topics, styles, beginnings.
#     """
#     return prompt

# %%
# def makePrompt(first_names,last_names,topic):
#     prompt = f"""
#     Your task is to write a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
#     the first names should be different from the following list: {first_names}
#     the last names should be different from the following list: {last_names}
#     the topic should be different from the following list: {topic}
#     Here is an example of what the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
#     ```
#     Voici une histoire passionnante sur un jeune garçon nommé Pierre <first name>. Il vivait dans un petit village appelé Saint-Étienne. Pierre <first name> Leblanc <last name> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <first name>. Ils devinrent rapidement les meilleurs amis. Pierre <first name> et Sophie <first name> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <first name> tomba malade et Sophie <first name> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <first name> se rétablit rapidement. Sophie <first name> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <first name> et Sophie <first name> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
#     ```
#     The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
#     The output should be a JSON object with the following keys: text, first_names, last_names, topics.
#     """
#     return prompt

# %%
def makePrompt(first_names,last_names,topic):
    prompt = f"""
    Your task is to write a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
    the first names should NOT be any element from the following list: {first_names}
    the last names should NOT be any element from the following list: {last_names}
    the topic should NOT be any element from the following list: {topic}
    The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example below.
    The output should ONLY be a JSON object with the following keys: text, first_names, last_names, topics.
    Here is an example of what the text in the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
    ```
    Voici une histoire passionnante sur un jeune garçon nommé Pierre <first name>. Il vivait dans un petit village appelé Saint-Étienne. Pierre <first name> Leblanc <last name> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <first name>. Ils devinrent rapidement les meilleurs amis. Pierre <first name> et Sophie <first name> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <first name> tomba malade et Sophie <first name> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <first name> se rétablit rapidement. Sophie <first name> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <first name> et Sophie <first name> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
    ```
    """
    return prompt

# %%
import json
def is_json(myjson):
  try:
    json.loads(myjson)
  except ValueError as e:
    return False
  return True

first_names = ["Pierre","Sophie"]
last_names = ["Leblanc"]
topic = []

# %%
# add texts in a loop to dataframe
for i in range(10):
    prompt = makePrompt(first_names,last_names,topic)
    response = get_completion(prompt)
    print("réponse complète : " + response)
    if is_json(response):
        response = json.loads(response)
        text = response["text"]
        print("le texte est : " + text)
        # get the contents of the "first_names" and "last_names" keys from the JSON object in the response and append them to the lists
        first_names = first_names + response["first_names"]
        last_names = last_names + response["last_names"]
        topic = topic + response["topics"]
        print("les prénoms sont : ")
        print(first_names)
        print("les noms de famille sont : ")
        print(last_names)
        print("les sujets sont : ")
        print(topic)
    else:
        text = response
        print(text)
    add_to_df(text)

df.head()
# Out:
# réponse complète : {
#   "text": "Voici une histoire passionnante sur une jeune femme nommée Camille <first name>. Elle vivait dans une petite ville appelée Saint-Louis. Camille <first name> Blanc <last name> aimait lire des livres et passer du temps dans la nature. Un jour, elle découvrit un vieux journal dans une librairie et décida de l'acheter. En rentrant chez elle, Camille <first name> commença à lire le journal et fut captivée par les histoires qu'il contenait. Chaque page était remplie d'aventures incroyables et de secrets mystérieux. Plus Camille <first name> lisait, plus elle se sentait transportée dans un autre monde. Elle était tellement absorbée par sa lecture qu'elle oublia tout ce qui se passait autour d'elle. Les jours passèrent et Camille <first name> ne pouvait pas s'arrêter de lire le journal. Chaque soir, elle se plongeait dans ses pages et vivait des moments de joie et de tristesse avec les personnages. Cette histoire passionnante lui permettait de s'évader de la réalité et de rêver d'aventures extraordinaires. Camille <first name> était reconnaissante d'avoir découvert ce journal et savait qu'elle continuerait à le lire encore et encore, pour toujours.",
#   "first_names": ["Camille", "Lucas", "Isabella", "Mohamed", "Anna"],
#   "last_names": ["Blanc", "Moreau", "Gonzalez", "Ali", "Smith"],
#   "topics": ["l'amitié", "les voyages", "le mystère", "la nature", "l'imagination"]
# }
# le texte est : Voici une histoire passionnante sur une jeune femme nommée Camille <first name>. Elle vivait dans une petite ville appelée Saint-Louis. Camille <first name> Blanc <last name> aimait lire des livres et passer du temps dans la nature. Un jour, elle découvrit un vieux journal dans une librairie et décida de l'acheter. En rentrant chez elle, Camille <first name> commença à lire le journal et fut captivée par les histoires qu'il contenait. Chaque page était remplie d'aventures incroyables et de secrets mystérieux. Plus Camille <first name> lisait, plus elle se sentait transportée dans un autre monde. Elle était tellement absorbée par sa lecture qu'elle oublia tout ce qui se passait autour d'elle. Les jours passèrent et Camille <first name> ne pouvait pas s'arrêter de lire le journal. Chaque soir, elle se plongeait dans ses pages et vivait des moments de joie et de tristesse avec les personnages. Cette histoire passionnante lui permettait de s'évader de la réalité et de rêver d'aventures extraordinaires. Camille <first name> était reconnaissante d'avoir découvert ce journal et savait qu'elle continuerait à le lire encore et encore, pour toujours.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination"]
# réponse complète : {
#   "text": "Voici une histoire fascinante sur une jeune femme nommée Emily <first name>. Elle vivait dans une grande ville appelée New York. Emily <first name> Blanc <last name> était une artiste talentueuse et passionnée par la peinture. Elle passait ses journées à créer des œuvres d'art magnifiques et à les exposer dans des galeries d'art. Un jour, lors d'une exposition, elle rencontra un homme mystérieux du nom de Sebastian <first name>. Il était charmant et avait une passion pour la musique. Emily <first name> et Sebastian <first name> commencèrent à passer du temps ensemble, partageant leur amour pour l'art et la musique. Leur relation grandit rapidement et ils tombèrent amoureux l'un de l'autre. Cependant, leur histoire d'amour fut mise à l'épreuve lorsque Sebastian <first name> dut partir en tournée avec son groupe de musique. Emily <first name> était triste mais comprit que c'était une opportunité pour Sebastian <first name> de réaliser ses rêves. Ils se promirent de rester en contact et de se retrouver dès que possible. Malgré la distance, leur amour resta fort et ils continuèrent à partager leur passion pour l'art et la musique. Finalement, Sebastian <first name> revint à New York et lui proposa de l'épouser. Emily <first name> était remplie de joie et accepta avec enthousiasme. Ils vécurent heureux pour toujours, créant de magnifiques œuvres d'art et de belles mélodies ensemble.",
#   "first_names": ["Emily", "Sebastian"],
#   "last_names": ["Blanc"],
#   "topics": ["l'art", "la musique"]
# }
# le texte est : Voici une histoire fascinante sur une jeune femme nommée Emily <first name>. Elle vivait dans une grande ville appelée New York. Emily <first name> Blanc <last name> était une artiste talentueuse et passionnée par la peinture. Elle passait ses journées à créer des œuvres d'art magnifiques et à les exposer dans des galeries d'art. Un jour, lors d'une exposition, elle rencontra un homme mystérieux du nom de Sebastian <first name>. Il était charmant et avait une passion pour la musique. Emily <first name> et Sebastian <first name> commencèrent à passer du temps ensemble, partageant leur amour pour l'art et la musique. Leur relation grandit rapidement et ils tombèrent amoureux l'un de l'autre. Cependant, leur histoire d'amour fut mise à l'épreuve lorsque Sebastian <first name> dut partir en tournée avec son groupe de musique. Emily <first name> était triste mais comprit que c'était une opportunité pour Sebastian <first name> de réaliser ses rêves. Ils se promirent de rester en contact et de se retrouver dès que possible. Malgré la distance, leur amour resta fort et ils continuèrent à partager leur passion pour l'art et la musique. Finalement, Sebastian <first name> revint à New York et lui proposa de l'épouser. Emily <first name> était remplie de joie et accepta avec enthousiasme. Ils vécurent heureux pour toujours, créant de magnifiques œuvres d'art et de belles mélodies ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique']
# réponse complète : {
#     "text": "Voici un texte fascinant sur une femme nommée Maria <first name>. Elle était une exploratrice intrépide qui parcourait le monde à la recherche de trésors cachés. Maria <first name> Blanc <last name> était connue pour sa détermination et son courage. Elle avait voyagé dans de nombreux pays exotiques, découvrant de nouvelles cultures et rencontrant des personnes fascinantes. Un jour, lors d'une expédition en Amazonie, Maria <first name> fit la rencontre d'un homme mystérieux nommé Alejandro <first name>. Il était un guide local qui connaissait la forêt comme sa poche. Maria <first name> et Alejandro <first name> devinrent amis et explorèrent ensemble les merveilles de la jungle. Ils découvrirent des plantes médicinales rares, observèrent des animaux sauvages et apprirent les coutumes des tribus indigènes. Leur amitié grandit au fil du temps et ils devinrent un duo d'aventuriers légendaire. Maria <first name> et Alejandro <first name> continuèrent à explorer le monde, repoussant les limites de leur imagination et vivant des aventures extraordinaires.",
#     "first_names": ["Maria", "Alejandro"],
#     "last_names": ["Blanc"],
#     "topics": ["l'exploration", "les aventures"]
# }
# le texte est : Voici un texte fascinant sur une femme nommée Maria <first name>. Elle était une exploratrice intrépide qui parcourait le monde à la recherche de trésors cachés. Maria <first name> Blanc <last name> était connue pour sa détermination et son courage. Elle avait voyagé dans de nombreux pays exotiques, découvrant de nouvelles cultures et rencontrant des personnes fascinantes. Un jour, lors d'une expédition en Amazonie, Maria <first name> fit la rencontre d'un homme mystérieux nommé Alejandro <first name>. Il était un guide local qui connaissait la forêt comme sa poche. Maria <first name> et Alejandro <first name> devinrent amis et explorèrent ensemble les merveilles de la jungle. Ils découvrirent des plantes médicinales rares, observèrent des animaux sauvages et apprirent les coutumes des tribus indigènes. Leur amitié grandit au fil du temps et ils devinrent un duo d'aventuriers légendaire. Maria <first name> et Alejandro <first name> continuèrent à explorer le monde, repoussant les limites de leur imagination et vivant des aventures extraordinaires.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures']
# réponse complète : {
#     "text": "Voici une histoire fascinante sur un jeune homme nommé Alejandro <first name>. Il vivait dans la belle ville de Paris. Alejandro <first name> Gonzalez <last name> était passionné par la gastronomie et rêvait de devenir un grand chef. Un jour, alors qu'il était en train de cuisiner dans son petit restaurant, Alejandro <first name> rencontra une femme incroyablement talentueuse nommée Maria <first name>. Maria <first name> Smith <last name> était une célèbre critique gastronomique qui était impressionnée par les talents culinaires d'Alejandro <first name>. Ils commencèrent à travailler ensemble pour créer des plats innovants et délicieux. Leur collaboration fut un succès et ils devinrent rapidement les chefs les plus renommés de la ville. Ensemble, Alejandro <first name> et Maria <first name> ouvrirent un restaurant étoilé au guide Michelin et continuèrent à éblouir les papilles des clients avec leurs créations uniques. Leur histoire est un témoignage de la passion et du talent qui peuvent transformer les rêves en réalité.",
#     "first_names": ["Alejandro", "Maria"],
#     "last_names": ["Gonzalez", "Smith"],
#     "topics": ["la gastronomie", "la collaboration"]
# }
# le texte est : Voici une histoire fascinante sur un jeune homme nommé Alejandro <first name>. Il vivait dans la belle ville de Paris. Alejandro <first name> Gonzalez <last name> était passionné par la gastronomie et rêvait de devenir un grand chef. Un jour, alors qu'il était en train de cuisiner dans son petit restaurant, Alejandro <first name> rencontra une femme incroyablement talentueuse nommée Maria <first name>. Maria <first name> Smith <last name> était une célèbre critique gastronomique qui était impressionnée par les talents culinaires d'Alejandro <first name>. Ils commencèrent à travailler ensemble pour créer des plats innovants et délicieux. Leur collaboration fut un succès et ils devinrent rapidement les chefs les plus renommés de la ville. Ensemble, Alejandro <first name> et Maria <first name> ouvrirent un restaurant étoilé au guide Michelin et continuèrent à éblouir les papilles des clients avec leurs créations uniques. Leur histoire est un témoignage de la passion et du talent qui peuvent transformer les rêves en réalité.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro', 'Alejandro', 'Maria']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc', 'Gonzalez', 'Smith']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures', 'la gastronomie', 'la collaboration']
# réponse complète : {
#   "text": "Voici une histoire fascinante sur un jeune homme nommé Alexander <first name>. Il vivait dans une grande ville appelée New York. Alexander <first name> Martinez <last name> était passionné par l'astronomie et passait des nuits à observer les étoiles. Un jour, lors d'une de ses observations, il rencontra une femme mystérieuse nommée Aurora <first name>. Ils se lièrent rapidement d'amitié. Alexander <first name> et Aurora <first name> passaient leurs soirées à discuter de l'univers et à rêver de voyages intergalactiques. Cependant, un jour, Alexander <first name> reçut une offre d'emploi pour travailler dans un observatoire à Paris. Aurora <first name> était triste de voir son ami partir, mais elle savait que c'était une opportunité unique pour lui. Alexander <first name> déménagea à Paris et devint un astronome renommé. Malgré la distance, lui et Aurora <first name> restaient en contact et partageaient leurs découvertes. Leur amitié était plus forte que jamais, même à des milliers de kilomètres de distance.",
#   "first_names": ["Alexander", "Aurora"],
#   "last_names": ["Martinez"],
#   "topics": ["l'astronomie"]
# }
# le texte est : Voici une histoire fascinante sur un jeune homme nommé Alexander <first name>. Il vivait dans une grande ville appelée New York. Alexander <first name> Martinez <last name> était passionné par l'astronomie et passait des nuits à observer les étoiles. Un jour, lors d'une de ses observations, il rencontra une femme mystérieuse nommée Aurora <first name>. Ils se lièrent rapidement d'amitié. Alexander <first name> et Aurora <first name> passaient leurs soirées à discuter de l'univers et à rêver de voyages intergalactiques. Cependant, un jour, Alexander <first name> reçut une offre d'emploi pour travailler dans un observatoire à Paris. Aurora <first name> était triste de voir son ami partir, mais elle savait que c'était une opportunité unique pour lui. Alexander <first name> déménagea à Paris et devint un astronome renommé. Malgré la distance, lui et Aurora <first name> restaient en contact et partageaient leurs découvertes. Leur amitié était plus forte que jamais, même à des milliers de kilomètres de distance.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro', 'Alejandro', 'Maria', 'Alexander', 'Aurora']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc', 'Gonzalez', 'Smith', 'Martinez']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures', 'la gastronomie', 'la collaboration', "l'astronomie"]
# réponse complète : {
#     "text": "Voici une histoire fascinante sur un jeune homme nommé Maxime <first name>. Il vivait dans une petite ville appelée Saint-Martin. Maxime <first name> Rodriguez <last name> était passionné par la technologie et aimait passer du temps à développer de nouvelles applications. Un jour, il rencontra une femme intelligente et ambitieuse nommée Emma <first name>. Ils partagèrent leur passion pour l'informatique et commencèrent à travailler sur un projet innovant ensemble. Maxime <first name> et Emma <first name> passaient leurs journées à coder et à discuter de leurs idées. Leur projet attira l'attention d'une grande entreprise technologique qui décida de les soutenir financièrement. Maxime <first name> et Emma <first name> étaient ravis de cette opportunité et travaillèrent dur pour réaliser leur vision. Grâce à leur détermination et à leur talent, leur application devint un énorme succès et changea la vie de nombreuses personnes. Maxime <first name> et Emma <first name> étaient fiers de leur accomplissement et continuèrent à innover dans le domaine de la technologie.",
#     "first_names": ["Maxime", "Emma"],
#     "last_names": ["Rodriguez"],
#     "topics": ["la technologie", "l'innovation"]
# }
# le texte est : Voici une histoire fascinante sur un jeune homme nommé Maxime <first name>. Il vivait dans une petite ville appelée Saint-Martin. Maxime <first name> Rodriguez <last name> était passionné par la technologie et aimait passer du temps à développer de nouvelles applications. Un jour, il rencontra une femme intelligente et ambitieuse nommée Emma <first name>. Ils partagèrent leur passion pour l'informatique et commencèrent à travailler sur un projet innovant ensemble. Maxime <first name> et Emma <first name> passaient leurs journées à coder et à discuter de leurs idées. Leur projet attira l'attention d'une grande entreprise technologique qui décida de les soutenir financièrement. Maxime <first name> et Emma <first name> étaient ravis de cette opportunité et travaillèrent dur pour réaliser leur vision. Grâce à leur détermination et à leur talent, leur application devint un énorme succès et changea la vie de nombreuses personnes. Maxime <first name> et Emma <first name> étaient fiers de leur accomplissement et continuèrent à innover dans le domaine de la technologie.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro', 'Alejandro', 'Maria', 'Alexander', 'Aurora', 'Maxime', 'Emma']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc', 'Gonzalez', 'Smith', 'Martinez', 'Rodriguez']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures', 'la gastronomie', 'la collaboration', "l'astronomie", 'la technologie', "l'innovation"]
# réponse complète : {
#     "text": "Voici une histoire fascinante sur un jeune homme nommé Thomas <first name>. Il vivait dans une petite ville appelée Lyon. Thomas <first name> Moreau <last name> était passionné par la science et aimait passer son temps à faire des expériences. Un jour, il rencontra une femme intelligente nommée Emma <first name>. Ils se lièrent rapidement d'amitié et commencèrent à travailler ensemble sur des projets scientifiques passionnants. Thomas <first name> et Emma <first name> passaient leurs journées à discuter de leurs découvertes et à chercher de nouvelles idées. Cependant, un jour, Thomas <first name> rencontra des difficultés dans ses recherches et se sentit découragé. Heureusement, grâce au soutien et à l'encouragement d'Emma <first name>, Thomas <first name> trouva la motivation pour surmonter ses obstacles. Emma <first name> était fière de voir son ami reprendre confiance en lui. Depuis ce jour, Thomas <first name> et Emma <first name> étaient inséparables et continuaient à repousser les limites de la science ensemble.",
#     "first_names": ["Thomas", "Emma"],
#     "last_names": ["Moreau"],
#     "topics": ["la science"]
# }
# le texte est : Voici une histoire fascinante sur un jeune homme nommé Thomas <first name>. Il vivait dans une petite ville appelée Lyon. Thomas <first name> Moreau <last name> était passionné par la science et aimait passer son temps à faire des expériences. Un jour, il rencontra une femme intelligente nommée Emma <first name>. Ils se lièrent rapidement d'amitié et commencèrent à travailler ensemble sur des projets scientifiques passionnants. Thomas <first name> et Emma <first name> passaient leurs journées à discuter de leurs découvertes et à chercher de nouvelles idées. Cependant, un jour, Thomas <first name> rencontra des difficultés dans ses recherches et se sentit découragé. Heureusement, grâce au soutien et à l'encouragement d'Emma <first name>, Thomas <first name> trouva la motivation pour surmonter ses obstacles. Emma <first name> était fière de voir son ami reprendre confiance en lui. Depuis ce jour, Thomas <first name> et Emma <first name> étaient inséparables et continuaient à repousser les limites de la science ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro', 'Alejandro', 'Maria', 'Alexander', 'Aurora', 'Maxime', 'Emma', 'Thomas', 'Emma']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc', 'Gonzalez', 'Smith', 'Martinez', 'Rodriguez', 'Moreau']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures', 'la gastronomie', 'la collaboration', "l'astronomie", 'la technologie', "l'innovation", 'la science']
# réponse complète : {
#   "text": "Voici une histoire captivante sur un jeune homme nommé Alejandro <first name>. Il venait d'un petit village appelé San Miguel. Alejandro <first name> Rodriguez <last name> était un passionné de sport et aimait passer du temps à jouer au football avec ses amis. Un jour, il fit la rencontre d'une fille incroyablement talentueuse appelée Aurora <first name>. Ils devinrent rapidement inséparables. Alejandro <first name> et Aurora <first name> passaient leurs journées à s'entraîner ensemble et à s'encourager mutuellement. Cependant, un jour, Alejandro <first name> se blessa gravement lors d'un match et Aurora <first name> fut très inquiète. Heureusement, grâce aux soins médicaux spécialisés et à sa détermination, Alejandro <first name> se rétablit lentement mais sûrement. Aurora <first name> était soulagée de voir son ami en voie de guérison. Depuis ce jour, Alejandro <first name> et Aurora <first name> continuèrent à s'entraîner ensemble, repoussant leurs limites et réalisant de grandes choses dans le monde du sport.",
#   "first_names": ["Alejandro", "Aurora"],
#   "last_names": ["Rodriguez"],
#   "topics": ["le sport"]
# }
# le texte est : Voici une histoire captivante sur un jeune homme nommé Alejandro <first name>. Il venait d'un petit village appelé San Miguel. Alejandro <first name> Rodriguez <last name> était un passionné de sport et aimait passer du temps à jouer au football avec ses amis. Un jour, il fit la rencontre d'une fille incroyablement talentueuse appelée Aurora <first name>. Ils devinrent rapidement inséparables. Alejandro <first name> et Aurora <first name> passaient leurs journées à s'entraîner ensemble et à s'encourager mutuellement. Cependant, un jour, Alejandro <first name> se blessa gravement lors d'un match et Aurora <first name> fut très inquiète. Heureusement, grâce aux soins médicaux spécialisés et à sa détermination, Alejandro <first name> se rétablit lentement mais sûrement. Aurora <first name> était soulagée de voir son ami en voie de guérison. Depuis ce jour, Alejandro <first name> et Aurora <first name> continuèrent à s'entraîner ensemble, repoussant leurs limites et réalisant de grandes choses dans le monde du sport.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro', 'Alejandro', 'Maria', 'Alexander', 'Aurora', 'Maxime', 'Emma', 'Thomas', 'Emma', 'Alejandro', 'Aurora']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc', 'Gonzalez', 'Smith', 'Martinez', 'Rodriguez', 'Moreau', 'Rodriguez']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures', 'la gastronomie', 'la collaboration', "l'astronomie", 'la technologie', "l'innovation", 'la science', 'le sport']
# réponse complète : {
#     "text": "Voici une histoire fascinante sur une jeune femme nommée Anna <first name>. Elle vivait dans une petite ville pittoresque appelée Bellefontaine. Anna <first name> Martinez <last name> aimait peindre et passer du temps dans la nature. Un jour, lors d'une promenade dans la forêt, elle rencontra un homme mystérieux nommé Sebastian <first name>. Ils se lièrent rapidement d'amitié et partagèrent leur passion pour l'art. Anna <first name> et Sebastian <first name> passaient leurs journées à créer des œuvres d'art inspirantes et à explorer de nouveaux endroits. Cependant, un jour, Anna <first name> reçut une invitation pour exposer ses peintures dans une galerie renommée à Paris. Elle était à la fois excitée et nerveuse à l'idée de présenter son travail au public. Grâce à l'encouragement de Sebastian <first name> et de sa famille, Anna <first name> surmonta ses doutes et réalisa son rêve. Son exposition fut un succès retentissant et elle devint une artiste reconnue dans le monde de l'art. Depuis ce jour, Anna <first name> et Sebastian <first name> continuaient à créer des chefs-d'œuvre ensemble et à inspirer les autres par leur talent et leur amitié.",
#     "first_names": ["Anna", "Sebastian"],
#     "last_names": ["Martinez"],
#     "topics": ["l'art", "l'amitié"]
# }
# le texte est : Voici une histoire fascinante sur une jeune femme nommée Anna <first name>. Elle vivait dans une petite ville pittoresque appelée Bellefontaine. Anna <first name> Martinez <last name> aimait peindre et passer du temps dans la nature. Un jour, lors d'une promenade dans la forêt, elle rencontra un homme mystérieux nommé Sebastian <first name>. Ils se lièrent rapidement d'amitié et partagèrent leur passion pour l'art. Anna <first name> et Sebastian <first name> passaient leurs journées à créer des œuvres d'art inspirantes et à explorer de nouveaux endroits. Cependant, un jour, Anna <first name> reçut une invitation pour exposer ses peintures dans une galerie renommée à Paris. Elle était à la fois excitée et nerveuse à l'idée de présenter son travail au public. Grâce à l'encouragement de Sebastian <first name> et de sa famille, Anna <first name> surmonta ses doutes et réalisa son rêve. Son exposition fut un succès retentissant et elle devint une artiste reconnue dans le monde de l'art. Depuis ce jour, Anna <first name> et Sebastian <first name> continuaient à créer des chefs-d'œuvre ensemble et à inspirer les autres par leur talent et leur amitié.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro', 'Alejandro', 'Maria', 'Alexander', 'Aurora', 'Maxime', 'Emma', 'Thomas', 'Emma', 'Alejandro', 'Aurora', 'Anna', 'Sebastian']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc', 'Gonzalez', 'Smith', 'Martinez', 'Rodriguez', 'Moreau', 'Rodriguez', 'Martinez']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures', 'la gastronomie', 'la collaboration', "l'astronomie", 'la technologie', "l'innovation", 'la science', 'le sport', "l'art", "l'amitié"]
# réponse complète : {
#   "text": "Voici une histoire fascinante sur un homme nommé Maxime <first name>. Il était originaire de Paris et travaillait comme ingénieur. Maxime <first name> Blanc <last name> était passionné par la technologie et aimait créer de nouvelles inventions. Un jour, il eut l'idée de concevoir une machine révolutionnaire qui pourrait résoudre les problèmes environnementaux. Maxime <first name> était déterminé à réaliser son rêve et passait de longues heures à travailler sur son projet. Pendant ce temps, il rencontra une femme charmante nommée Aurora <first name>. Aurora <first name> Moreau <last name> était une artiste talentueuse et était immédiatement attirée par l'esprit créatif de Maxime <first name>. Ils commencèrent à travailler ensemble, combinant l'art et la technologie pour sensibiliser les gens aux problèmes environnementaux. Leur collaboration donna naissance à des œuvres d'art uniques et à des inventions innovantes. Maxime <first name> et Aurora <first name> étaient admirés pour leur vision et leur engagement envers la préservation de la nature. Leur travail inspira de nombreuses personnes à agir et à prendre soin de l'environnement. Maxime <first name> et Aurora <first name> étaient fiers de l'impact qu'ils avaient sur le monde et ils continuèrent à travailler ensemble pour un avenir plus durable.",
#   "first_names": ["Maxime", "Aurora"],
#   "last_names": ["Blanc", "Moreau"],
#   "topics": ["l'environnement", "la technologie"]
# }
# le texte est : Voici une histoire fascinante sur un homme nommé Maxime <first name>. Il était originaire de Paris et travaillait comme ingénieur. Maxime <first name> Blanc <last name> était passionné par la technologie et aimait créer de nouvelles inventions. Un jour, il eut l'idée de concevoir une machine révolutionnaire qui pourrait résoudre les problèmes environnementaux. Maxime <first name> était déterminé à réaliser son rêve et passait de longues heures à travailler sur son projet. Pendant ce temps, il rencontra une femme charmante nommée Aurora <first name>. Aurora <first name> Moreau <last name> était une artiste talentueuse et était immédiatement attirée par l'esprit créatif de Maxime <first name>. Ils commencèrent à travailler ensemble, combinant l'art et la technologie pour sensibiliser les gens aux problèmes environnementaux. Leur collaboration donna naissance à des œuvres d'art uniques et à des inventions innovantes. Maxime <first name> et Aurora <first name> étaient admirés pour leur vision et leur engagement envers la préservation de la nature. Leur travail inspira de nombreuses personnes à agir et à prendre soin de l'environnement. Maxime <first name> et Aurora <first name> étaient fiers de l'impact qu'ils avaient sur le monde et ils continuèrent à travailler ensemble pour un avenir plus durable.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Camille', 'Lucas', 'Isabella', 'Mohamed', 'Anna', 'Emily', 'Sebastian', 'Maria', 'Alejandro', 'Alejandro', 'Maria', 'Alexander', 'Aurora', 'Maxime', 'Emma', 'Thomas', 'Emma', 'Alejandro', 'Aurora', 'Anna', 'Sebastian', 'Maxime', 'Aurora']
# les noms de famille sont :
# ['Leblanc', 'Blanc', 'Moreau', 'Gonzalez', 'Ali', 'Smith', 'Blanc', 'Blanc', 'Gonzalez', 'Smith', 'Martinez', 'Rodriguez', 'Moreau', 'Rodriguez', 'Martinez', 'Blanc', 'Moreau']
# les sujets sont :
# ["l'amitié", 'les voyages', 'le mystère', 'la nature', "l'imagination", "l'art", 'la musique', "l'exploration", 'les aventures', 'la gastronomie', 'la collaboration', "l'astronomie", 'la technologie', "l'innovation", 'la science', 'le sport', "l'art", "l'amitié", "l'environnement", 'la technologie']
#                                                 text
# 0  Voici une histoire passionnante sur une jeune ...
# 1  Voici une histoire fascinante sur une jeune fe...
# 2  Voici un texte fascinant sur une femme nommée ...
# 3  Voici une histoire fascinante sur un jeune hom...
# 4  Voici une histoire fascinante sur un jeune hom...

# %%
df.head(10)
# Out:
#                                                 text
# 0  Voici une histoire passionnante sur une jeune ...
# 1  Voici une histoire fascinante sur une jeune fe...
# 2  Voici un texte fascinant sur une femme nommée ...
# 3  Voici une histoire fascinante sur un jeune hom...
# 4  Voici une histoire fascinante sur un jeune hom...
# 5  Voici une histoire fascinante sur un jeune hom...
# 6  Voici une histoire fascinante sur un jeune hom...
# 7  Voici une histoire captivante sur un jeune hom...
# 8  Voici une histoire fascinante sur une jeune fe...
# 9  Voici une histoire fascinante sur un homme nom...
