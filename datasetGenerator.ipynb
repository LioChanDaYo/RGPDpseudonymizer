# %%
import pandas as pd
# create an empty dataframe with only one column named "text"
df = pd.DataFrame(columns=["text"])

# %%
# make a function to read a string in a variable and concatenate it to the dataframe
def add_to_df(text):
    global df
    df = pd.concat([df, pd.DataFrame([text], columns=["text"])], ignore_index=True)

# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# # modèle de fonctionnement des prompts avec un texte
# text = f"""
# You should express what you want a model to do by \ 
# providing instructions that are as clear and \ 
# specific as you can possibly make them. \ 
# This will guide the model towards the desired output, \ 
# and reduce the chances of receiving irrelevant \ 
# or incorrect responses. Don't confuse writing a \ 
# clear prompt with writing a short prompt. \ 
# In many cases, longer prompts provide more clarity \ 
# and context for the model, which can lead to \ 
# more detailed and relevant outputs.
# """
# prompt = f"""
# Summarize the text delimited by triple backticks \ 
# into a single sentence.
# ```{text}```
# """
# response = get_completion(prompt)
# print(response)

# %%
# # text generation
# prompt = f"""
# Génère un court texte en Français. \
# Une fois le texte généré, recherche tous les prénoms, noms de famille et noms d'entreprises dans ce texte. \
# Ajoute la mention <first name> après chaque occurrence de chaque prénom ; ajoute la mention <last name> après chaque occurrence de chaque nom de famille ; ajoute la mention mention <company name> après chaque occurrence de chaque nom d'entreprise."
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to perform the actions described below:
# 1 - Generate a short text in French.
# 2 - Once generated, look for proper names.
# 3 - In the text from step 1, add the mention <first name> after each first name, add the mention <last name> after each last name.
# Here is an example of what the output should look like. Don't make your text about a similar topic or it will be rejected:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
# Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# add_to_df(response)
# df.head()

# %%
# # a function that make the prompt from two lists of first names and last names
# def makePrompt(first_names,last_names,topic,style,beginning):
#     prompt = f"""
#     Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
#     Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
#     ```
#     Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
#     ```
#     The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
#     the first names should be different from the following list: {first_names}
#     the last names should be different from the following list: {last_names}
#     the topic should be different from the following list: {topic}
#     the style should be different from the following list: {style}
#     the beginning should be different from the following list: {beginning}
#     Here are a few suggestions of topics: judiciaire, politique, sport, économie, santé, culture, technologie, environnement, éducation, société, international, sciences, médias, religion, faits divers, people, etc.
#     Here are few suggestions of styles: informatif, narratif, descriptif, argumentatif, explicatif, injonctif, poétique, humoristique, etc.
#     The output should be a JSON object with the following keys: text, first_names, last_names, topics, styles, beginnings.
#     """
#     return prompt

# %%
# def makePrompt(first_names,last_names,topic):
#     prompt = f"""
#     Your task is to write a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
#     the first names should be different from the following list: {first_names}
#     the last names should be different from the following list: {last_names}
#     the topic should be different from the following list: {topic}
#     Here is an example of what the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
#     ```
#     Voici une histoire passionnante sur un jeune garçon nommé Pierre <first name>. Il vivait dans un petit village appelé Saint-Étienne. Pierre <first name> Leblanc <last name> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <first name>. Ils devinrent rapidement les meilleurs amis. Pierre <first name> et Sophie <first name> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <first name> tomba malade et Sophie <first name> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <first name> se rétablit rapidement. Sophie <first name> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <first name> et Sophie <first name> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
#     ```
#     The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
#     The output should be a JSON object with the following keys: text, first_names, last_names, topics.
#     """
#     return prompt

# %%
def makePrompt(first_names,last_names,topic,beginning):
    prompt = f"""
    Your task is to write a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
    the first names should NOT be any element from the following list: {first_names}
    the last names should NOT be any element from the following list: {last_names}
    the topic should NOT be any element from the following list: {topic}
    the beginning should NOT be any element from the following list: {beginning}
    The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example below.
    The output should ONLY be a JSON object with the following keys: text, first_names, last_names, topics, beginnings.
    Here is an example of what the text in the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
    ```
    Voici une histoire passionnante sur un jeune garçon nommé Pierre <first name>. Il vivait dans un petit village appelé Saint-Étienne. Pierre <first name> Leblanc <last name> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <first name>. Ils devinrent rapidement les meilleurs amis. Pierre <first name> et Sophie <first name> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <first name> tomba malade et Sophie <first name> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <first name> se rétablit rapidement. Sophie <first name> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <first name> et Sophie <first name> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
    ```
    """
    return prompt

# %%
import json
def is_json(myjson):
  try:
    json.loads(myjson)
  except ValueError as e:
    return False
  return True

first_names = ["Pierre","Sophie"]
last_names = ["Leblanc"]
topic = []
beginning = ["Voici une histoire"]

# %%
# add texts in a loop to dataframe
for i in range(10):
    prompt = makePrompt(first_names,last_names,topic,beginning)
    response = get_completion(prompt)
    print("réponse complète : " + response)
    if is_json(response):
        response = json.loads(response)
        text = response["text"]
        print("le texte est : " + text)
        # get the contents of the "first_names" and "last_names" keys from the JSON object in the response and append them to the lists
        first_names = first_names + response["first_names"]
        last_names = last_names + response["last_names"]
        topic = topic + response["topics"]
        beginning = beginning + response["beginnings"]
        print("les prénoms sont : ")
        print(first_names)
        print("les noms de famille sont : ")
        print(last_names)
        print("les sujets sont : ")
        print(topic)
        print("les débuts sont : ")
        print(beginning)
    else:
        text = response
        print(text)
    add_to_df(text)

df.head()
# Out:
# réponse complète : {
#     "text": "Voici une histoire fascinante sur une jeune femme nommée Emma <first name>. Elle vivait dans une petite ville appelée Lyon. Emma <first name> Dubois <last name> aimait dessiner et passer du temps dans les musées. Un jour, elle visita un musée d'art et rencontra un homme mystérieux nommé Alejandro <first name>. Ils se lièrent rapidement d'amitié grâce à leur passion commune pour l'art. Emma <first name> et Alejandro <first name> passaient leurs journées à discuter de peinture et à visiter des galeries. Cependant, un jour, Emma <first name> reçut une invitation pour exposer ses propres œuvres dans une galerie prestigieuse. Elle était à la fois excitée et nerveuse. Alejandro <first name> l'encouragea à saisir cette opportunité et à partager son talent avec le monde. Grâce à son soutien, Emma <first name> présenta avec succès ses créations lors de l'exposition. Alejandro <first name> était fier de son amie et l'admiration grandit entre eux. Depuis ce jour, Emma <first name> et Alejandro <first name> étaient inséparables et partageaient de nombreux moments d'inspiration et d'émerveillement artistique ensemble.",
#     "first_names": ["Emma", "Alejandro"],
#     "last_names": ["Dubois"],
#     "topics": ["art", "musées", "exposition"],
#     "beginnings": ["Il était une fois", "Dans un monde lointain"]
# }
# le texte est : Voici une histoire fascinante sur une jeune femme nommée Emma <first name>. Elle vivait dans une petite ville appelée Lyon. Emma <first name> Dubois <last name> aimait dessiner et passer du temps dans les musées. Un jour, elle visita un musée d'art et rencontra un homme mystérieux nommé Alejandro <first name>. Ils se lièrent rapidement d'amitié grâce à leur passion commune pour l'art. Emma <first name> et Alejandro <first name> passaient leurs journées à discuter de peinture et à visiter des galeries. Cependant, un jour, Emma <first name> reçut une invitation pour exposer ses propres œuvres dans une galerie prestigieuse. Elle était à la fois excitée et nerveuse. Alejandro <first name> l'encouragea à saisir cette opportunité et à partager son talent avec le monde. Grâce à son soutien, Emma <first name> présenta avec succès ses créations lors de l'exposition. Alejandro <first name> était fier de son amie et l'admiration grandit entre eux. Depuis ce jour, Emma <first name> et Alejandro <first name> étaient inséparables et partageaient de nombreux moments d'inspiration et d'émerveillement artistique ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro']
# les noms de famille sont :
# ['Leblanc', 'Dubois']
# les sujets sont :
# ['art', 'musées', 'exposition']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain']
# réponse complète : {
#     "text": "Il était une fois un homme nommé Jacques <first name> Dupont <last name>. Il était un grand passionné de cuisine et rêvait d'ouvrir son propre restaurant. Jacques <first name> avait grandi en France et avait appris les secrets de la cuisine française auprès de sa grand-mère. Il était connu pour ses plats délicieux et sa créativité culinaire. Un jour, Jacques <first name> décida de réaliser son rêve et d'ouvrir son restaurant à Paris. Il travailla dur pour trouver le lieu idéal, créer un menu alléchant et recruter une équipe talentueuse. Finalement, le jour d'ouverture arriva et le restaurant de Jacques <first name> fut un grand succès. Les clients affluaient pour goûter ses plats savoureux et découvrir son style unique. Jacques <first name> était comblé de voir son rêve se réaliser. Il continua à innover et à surprendre ses clients avec de nouvelles créations culinaires. Son restaurant devint rapidement l'un des plus prisés de la ville. Jacques <first name> était fier de son parcours et de tout ce qu'il avait accompli. Il était heureux de partager sa passion pour la cuisine avec le monde entier.",
#     "first_names": ["Jacques", "Liam", "Sofia", "Miguel", "Elena"],
#     "last_names": ["Dupont", "Smith", "Gonzalez", "Rossi", "Müller"],
#     "topics": ["science", "voyages", "histoire", "sport", "technologie"],
#     "beginnings": ["Il y avait une fois", "Autrefois, dans un pays lointain", "Il y a bien longtemps", "Au cœur d'une ville animée"]
# }
# le texte est : Il était une fois un homme nommé Jacques <first name> Dupont <last name>. Il était un grand passionné de cuisine et rêvait d'ouvrir son propre restaurant. Jacques <first name> avait grandi en France et avait appris les secrets de la cuisine française auprès de sa grand-mère. Il était connu pour ses plats délicieux et sa créativité culinaire. Un jour, Jacques <first name> décida de réaliser son rêve et d'ouvrir son restaurant à Paris. Il travailla dur pour trouver le lieu idéal, créer un menu alléchant et recruter une équipe talentueuse. Finalement, le jour d'ouverture arriva et le restaurant de Jacques <first name> fut un grand succès. Les clients affluaient pour goûter ses plats savoureux et découvrir son style unique. Jacques <first name> était comblé de voir son rêve se réaliser. Il continua à innover et à surprendre ses clients avec de nouvelles créations culinaires. Son restaurant devint rapidement l'un des plus prisés de la ville. Jacques <first name> était fier de son parcours et de tout ce qu'il avait accompli. Il était heureux de partager sa passion pour la cuisine avec le monde entier.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée"]
# réponse complète : {
#     "text": "Voici une histoire incroyable sur une jeune femme nommée Emma <first name>. Elle vivait dans une petite ville appelée Montpellier. Emma <first name> Dubois <last name> était passionnée par la musique et passait son temps à jouer de la guitare. Un jour, elle rencontra un homme fascinant nommé Alejandro <first name>. Ils partageaient la même passion pour la musique et devinrent rapidement de grands amis. Emma <first name> et Alejandro <first name> passaient leurs journées à composer des chansons et à se produire dans des petits concerts locaux. Leur musique était si captivante qu'ils gagnèrent en popularité et commencèrent à jouer dans de plus grandes salles. Cependant, un jour, Emma <first name> perdit sa voix à cause d'une infection. Alejandro <first name> fut très inquiet pour son amie. Heureusement, grâce à des traitements médicaux et à la rééducation vocale, Emma <first name> retrouva sa voix et put à nouveau chanter avec passion. Alejandro <first name> était soulagé de voir son amie retrouver sa passion. Depuis ce jour, Emma <first name> et Alejandro <first name> continuaient à faire de la musique ensemble et partageaient de nombreux moments magiques sur scène.",
#     "first_names": ["Lucas", "Léa", "Maxime", "Julia", "Sebastian", "Maria", "Hugo", "Isabella"],
#     "last_names": ["Martin", "Lefevre", "Lopez", "Garcia", "Schmidt", "Roux", "Ricci", "Fischer"],
#     "topics": ["cinéma", "littérature", "cuisine", "nature", "mode", "architecture", "philosophie", "psychologie"],
#     "beginnings": ["Il était une fois", "Dans un pays lointain", "Il y a bien longtemps", "Au cœur d'une ville animée", "Autrefois, dans une petite ville", "Voici une histoire fascinante", "Il y avait une fois"]
# }
# le texte est : Voici une histoire incroyable sur une jeune femme nommée Emma <first name>. Elle vivait dans une petite ville appelée Montpellier. Emma <first name> Dubois <last name> était passionnée par la musique et passait son temps à jouer de la guitare. Un jour, elle rencontra un homme fascinant nommé Alejandro <first name>. Ils partageaient la même passion pour la musique et devinrent rapidement de grands amis. Emma <first name> et Alejandro <first name> passaient leurs journées à composer des chansons et à se produire dans des petits concerts locaux. Leur musique était si captivante qu'ils gagnèrent en popularité et commencèrent à jouer dans de plus grandes salles. Cependant, un jour, Emma <first name> perdit sa voix à cause d'une infection. Alejandro <first name> fut très inquiet pour son amie. Heureusement, grâce à des traitements médicaux et à la rééducation vocale, Emma <first name> retrouva sa voix et put à nouveau chanter avec passion. Alejandro <first name> était soulagé de voir son amie retrouver sa passion. Depuis ce jour, Emma <first name> et Alejandro <first name> continuaient à faire de la musique ensemble et partageaient de nombreux moments magiques sur scène.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena', 'Lucas', 'Léa', 'Maxime', 'Julia', 'Sebastian', 'Maria', 'Hugo', 'Isabella']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller', 'Martin', 'Lefevre', 'Lopez', 'Garcia', 'Schmidt', 'Roux', 'Ricci', 'Fischer']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie', 'cinéma', 'littérature', 'cuisine', 'nature', 'mode', 'architecture', 'philosophie', 'psychologie']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Il était une fois', 'Dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Autrefois, dans une petite ville', 'Voici une histoire fascinante', 'Il y avait une fois']
# réponse complète : {
#     "text": "Voici une histoire fascinante sur une jeune femme nommée Amara Gutiérrez. Elle vivait dans une petite ville pittoresque appelée Saint-Martin. Amara Gutiérrez Schmidt aimait explorer les montagnes et passer du temps avec ses amis. Un jour, elle rencontra un homme mystérieux nommé Elijah Nguyen. Ils devinrent rapidement les meilleurs amis. Amara Gutiérrez et Elijah Nguyen passaient leurs journées à se promener dans les ruelles étroites de la ville et à discuter de leurs rêves. Cependant, un jour, Amara Gutiérrez eut un accident et Elijah Nguyen fut très inquiet. Heureusement, grâce aux soins attentifs des médecins, Amara Gutiérrez se rétablit rapidement. Elijah Nguyen était soulagé de voir son amie en bonne santé. Depuis ce jour, Amara Gutiérrez et Elijah Nguyen étaient inséparables et partageaient de nombreux moments de bonheur ensemble.",
#     "first_names": ["Amara", "Elijah"],
#     "last_names": ["Gutiérrez", "Nguyen"],
#     "topics": ["amitié", "aventure", "passion", "découverte"],
#     "beginnings": ["Il y a bien longtemps", "Au cœur d'une forêt enchantée", "Dans un monde fascinant"]
# }
# le texte est : Voici une histoire fascinante sur une jeune femme nommée Amara Gutiérrez. Elle vivait dans une petite ville pittoresque appelée Saint-Martin. Amara Gutiérrez Schmidt aimait explorer les montagnes et passer du temps avec ses amis. Un jour, elle rencontra un homme mystérieux nommé Elijah Nguyen. Ils devinrent rapidement les meilleurs amis. Amara Gutiérrez et Elijah Nguyen passaient leurs journées à se promener dans les ruelles étroites de la ville et à discuter de leurs rêves. Cependant, un jour, Amara Gutiérrez eut un accident et Elijah Nguyen fut très inquiet. Heureusement, grâce aux soins attentifs des médecins, Amara Gutiérrez se rétablit rapidement. Elijah Nguyen était soulagé de voir son amie en bonne santé. Depuis ce jour, Amara Gutiérrez et Elijah Nguyen étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena', 'Lucas', 'Léa', 'Maxime', 'Julia', 'Sebastian', 'Maria', 'Hugo', 'Isabella', 'Amara', 'Elijah']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller', 'Martin', 'Lefevre', 'Lopez', 'Garcia', 'Schmidt', 'Roux', 'Ricci', 'Fischer', 'Gutiérrez', 'Nguyen']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie', 'cinéma', 'littérature', 'cuisine', 'nature', 'mode', 'architecture', 'philosophie', 'psychologie', 'amitié', 'aventure', 'passion', 'découverte']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Il était une fois', 'Dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Autrefois, dans une petite ville', 'Voici une histoire fascinante', 'Il y avait une fois', 'Il y a bien longtemps', "Au cœur d'une forêt enchantée", 'Dans un monde fascinant']
# réponse complète : {
#     "text": "Une histoire fascinante sur une jeune fille nommée Amara <first name>. Elle vivait dans une grande ville appelée New York. Amara <first name> Fischer <last name> aimait explorer les rues animées de la ville et découvrir de nouveaux endroits. Un jour, elle rencontra un garçon passionné de musique nommé Liam <first name>. Ils se lièrent d'amitié grâce à leur amour commun pour la musique. Amara <first name> et Liam <first name> passaient leurs journées à écouter de la musique, à jouer d'instruments et à chanter ensemble. Cependant, un jour, Amara <first name> reçut une opportunité de participer à une compétition musicale internationale. Elle fut très excitée mais aussi inquiète de quitter ses amis et sa famille. Heureusement, grâce à leur soutien et à leur encouragement, Amara <first name> décida de saisir cette chance unique. Liam <first name> était triste de voir son amie partir, mais il savait qu'elle poursuivait ses rêves. Depuis ce jour, Amara <first name> a parcouru le monde avec sa musique, mais elle n'oublie jamais les moments de bonheur partagés avec Liam <first name>.",
#     "first_names": ["Amara", "Liam"],
#     "last_names": ["Fischer"],
#     "topics": ["musique"],
#     "beginnings": ["Une histoire fascinante sur une jeune fille nommée Amara <first name>."]
# }
# le texte est : Une histoire fascinante sur une jeune fille nommée Amara <first name>. Elle vivait dans une grande ville appelée New York. Amara <first name> Fischer <last name> aimait explorer les rues animées de la ville et découvrir de nouveaux endroits. Un jour, elle rencontra un garçon passionné de musique nommé Liam <first name>. Ils se lièrent d'amitié grâce à leur amour commun pour la musique. Amara <first name> et Liam <first name> passaient leurs journées à écouter de la musique, à jouer d'instruments et à chanter ensemble. Cependant, un jour, Amara <first name> reçut une opportunité de participer à une compétition musicale internationale. Elle fut très excitée mais aussi inquiète de quitter ses amis et sa famille. Heureusement, grâce à leur soutien et à leur encouragement, Amara <first name> décida de saisir cette chance unique. Liam <first name> était triste de voir son amie partir, mais il savait qu'elle poursuivait ses rêves. Depuis ce jour, Amara <first name> a parcouru le monde avec sa musique, mais elle n'oublie jamais les moments de bonheur partagés avec Liam <first name>.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena', 'Lucas', 'Léa', 'Maxime', 'Julia', 'Sebastian', 'Maria', 'Hugo', 'Isabella', 'Amara', 'Elijah', 'Amara', 'Liam']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller', 'Martin', 'Lefevre', 'Lopez', 'Garcia', 'Schmidt', 'Roux', 'Ricci', 'Fischer', 'Gutiérrez', 'Nguyen', 'Fischer']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie', 'cinéma', 'littérature', 'cuisine', 'nature', 'mode', 'architecture', 'philosophie', 'psychologie', 'amitié', 'aventure', 'passion', 'découverte', 'musique']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Il était une fois', 'Dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Autrefois, dans une petite ville', 'Voici une histoire fascinante', 'Il y avait une fois', 'Il y a bien longtemps', "Au cœur d'une forêt enchantée", 'Dans un monde fascinant', 'Une histoire fascinante sur une jeune fille nommée Amara <first name>.']
# réponse complète : {
#     "text": "Il était une fois une histoire incroyable sur une jeune femme nommée Isabella <first name>. Elle vivait dans un petit village pittoresque appelé Montagneux. Isabella <first name> Fischer <last name> était connue pour sa passion pour la musique et son talent exceptionnel pour jouer du piano. Chaque jour, elle passait des heures à pratiquer et à perfectionner son art. Un jour, alors qu'elle se produisait lors d'un concert local, elle rencontra un jeune homme charmant nommé Lucas <first name>. Lucas <first name> Gutiérrez <last name> était un talentueux guitariste et ils partageaient une passion commune pour la musique. Ils commencèrent à jouer ensemble et à créer de magnifiques mélodies. Leur musique était si puissante et émouvante qu'elle touchait le cœur de tous ceux qui l'écoutaient. Isabella <first name> et Lucas <first name> devinrent rapidement célèbres dans le monde de la musique et leurs concerts étaient toujours complets. Ils continuaient à écrire de nouvelles chansons et à inspirer les autres avec leur talent unique. Isabella <first name> et Lucas <first name> étaient un duo musical extraordinaire et leur amour pour la musique les unissait encore plus.",
#     "first_names": ["Isabella", "Lucas"],
#     "last_names": ["Fischer", "Gutiérrez"],
#     "topics": ["musique"],
#     "beginnings": ["Il était une fois une histoire incroyable", "Il était une fois une jeune femme nommée Isabella", "Il y avait une fois une talentueuse pianiste nommée Isabella", "Dans un petit village pittoresque appelé Montagneux vivait une jeune femme nommée Isabella"]
# }
# le texte est : Il était une fois une histoire incroyable sur une jeune femme nommée Isabella <first name>. Elle vivait dans un petit village pittoresque appelé Montagneux. Isabella <first name> Fischer <last name> était connue pour sa passion pour la musique et son talent exceptionnel pour jouer du piano. Chaque jour, elle passait des heures à pratiquer et à perfectionner son art. Un jour, alors qu'elle se produisait lors d'un concert local, elle rencontra un jeune homme charmant nommé Lucas <first name>. Lucas <first name> Gutiérrez <last name> était un talentueux guitariste et ils partageaient une passion commune pour la musique. Ils commencèrent à jouer ensemble et à créer de magnifiques mélodies. Leur musique était si puissante et émouvante qu'elle touchait le cœur de tous ceux qui l'écoutaient. Isabella <first name> et Lucas <first name> devinrent rapidement célèbres dans le monde de la musique et leurs concerts étaient toujours complets. Ils continuaient à écrire de nouvelles chansons et à inspirer les autres avec leur talent unique. Isabella <first name> et Lucas <first name> étaient un duo musical extraordinaire et leur amour pour la musique les unissait encore plus.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena', 'Lucas', 'Léa', 'Maxime', 'Julia', 'Sebastian', 'Maria', 'Hugo', 'Isabella', 'Amara', 'Elijah', 'Amara', 'Liam', 'Isabella', 'Lucas']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller', 'Martin', 'Lefevre', 'Lopez', 'Garcia', 'Schmidt', 'Roux', 'Ricci', 'Fischer', 'Gutiérrez', 'Nguyen', 'Fischer', 'Fischer', 'Gutiérrez']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie', 'cinéma', 'littérature', 'cuisine', 'nature', 'mode', 'architecture', 'philosophie', 'psychologie', 'amitié', 'aventure', 'passion', 'découverte', 'musique', 'musique']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Il était une fois', 'Dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Autrefois, dans une petite ville', 'Voici une histoire fascinante', 'Il y avait une fois', 'Il y a bien longtemps', "Au cœur d'une forêt enchantée", 'Dans un monde fascinant', 'Une histoire fascinante sur une jeune fille nommée Amara <first name>.', 'Il était une fois une histoire incroyable', 'Il était une fois une jeune femme nommée Isabella', 'Il y avait une fois une talentueuse pianiste nommée Isabella', 'Dans un petit village pittoresque appelé Montagneux vivait une jeune femme nommée Isabella']
# réponse complète : {
#   "text": "Voici une histoire captivante sur un jeune homme nommé Lucas <first name>. Il vivait dans une grande ville appelée Paris. Lucas <first name> Müller <last name> était un passionné de musique et passait la plupart de son temps à jouer de la guitare. Un jour, lors d'une soirée dans un bar local, Lucas <first name> fit la rencontre d'une jeune femme mystérieuse nommée Elena <first name>. Elle était une talentueuse chanteuse et leurs voix se mariaient parfaitement. Lucas <first name> et Elena <first name> commencèrent à se produire ensemble et à émerveiller le public avec leur musique envoûtante. Leur duo devint rapidement célèbre dans toute la ville. Cependant, malgré leur succès, Lucas <first name> et Elena <first name> restèrent humbles et dévoués à leur passion. Ils continuaient à créer de la musique ensemble et à inspirer les autres. Lucas <first name> et Elena <first name> étaient non seulement des partenaires musicaux, mais aussi de véritables amis. Leur amitié sincère était évidente dans chaque note qu'ils jouaient. Ils partageaient des moments de joie, de tristesse et d'espoir à travers leur musique. Lucas <first name> et Elena <first name> étaient une preuve vivante que la musique pouvait unir les âmes et transcender les barrières. Leur histoire était une source d'inspiration pour tous ceux qui rêvaient de suivre leur passion.",
#   "first_names": ["Lucas", "Elena"],
#   "last_names": ["Müller"],
#   "topics": ["musique"],
#   "beginnings": ["Voici une histoire captivante", "Il vivait dans une grande ville", "Lucas <first name> Müller <last name> était un passionné de musique"]
# }
# le texte est : Voici une histoire captivante sur un jeune homme nommé Lucas <first name>. Il vivait dans une grande ville appelée Paris. Lucas <first name> Müller <last name> était un passionné de musique et passait la plupart de son temps à jouer de la guitare. Un jour, lors d'une soirée dans un bar local, Lucas <first name> fit la rencontre d'une jeune femme mystérieuse nommée Elena <first name>. Elle était une talentueuse chanteuse et leurs voix se mariaient parfaitement. Lucas <first name> et Elena <first name> commencèrent à se produire ensemble et à émerveiller le public avec leur musique envoûtante. Leur duo devint rapidement célèbre dans toute la ville. Cependant, malgré leur succès, Lucas <first name> et Elena <first name> restèrent humbles et dévoués à leur passion. Ils continuaient à créer de la musique ensemble et à inspirer les autres. Lucas <first name> et Elena <first name> étaient non seulement des partenaires musicaux, mais aussi de véritables amis. Leur amitié sincère était évidente dans chaque note qu'ils jouaient. Ils partageaient des moments de joie, de tristesse et d'espoir à travers leur musique. Lucas <first name> et Elena <first name> étaient une preuve vivante que la musique pouvait unir les âmes et transcender les barrières. Leur histoire était une source d'inspiration pour tous ceux qui rêvaient de suivre leur passion.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena', 'Lucas', 'Léa', 'Maxime', 'Julia', 'Sebastian', 'Maria', 'Hugo', 'Isabella', 'Amara', 'Elijah', 'Amara', 'Liam', 'Isabella', 'Lucas', 'Lucas', 'Elena']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller', 'Martin', 'Lefevre', 'Lopez', 'Garcia', 'Schmidt', 'Roux', 'Ricci', 'Fischer', 'Gutiérrez', 'Nguyen', 'Fischer', 'Fischer', 'Gutiérrez', 'Müller']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie', 'cinéma', 'littérature', 'cuisine', 'nature', 'mode', 'architecture', 'philosophie', 'psychologie', 'amitié', 'aventure', 'passion', 'découverte', 'musique', 'musique', 'musique']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Il était une fois', 'Dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Autrefois, dans une petite ville', 'Voici une histoire fascinante', 'Il y avait une fois', 'Il y a bien longtemps', "Au cœur d'une forêt enchantée", 'Dans un monde fascinant', 'Une histoire fascinante sur une jeune fille nommée Amara <first name>.', 'Il était une fois une histoire incroyable', 'Il était une fois une jeune femme nommée Isabella', 'Il y avait une fois une talentueuse pianiste nommée Isabella', 'Dans un petit village pittoresque appelé Montagneux vivait une jeune femme nommée Isabella', 'Voici une histoire captivante', 'Il vivait dans une grande ville', 'Lucas <first name> Müller <last name> était un passionné de musique']
# réponse complète : {
#     "text": "Voici une histoire fascinante sur une jeune femme nommée Amélie <first name>. Elle vivait dans une petite ville pittoresque appelée Bellefontaine. Amélie <first name> Rossignol <last name> était une passionnée de photographie et passait la plupart de son temps à explorer les paysages magnifiques qui l'entouraient. Un jour, lors d'une de ses escapades, elle rencontra un homme mystérieux nommé Alejandro <first name>. Alejandro <first name> Santos <last name> était un voyageur du monde qui avait parcouru les quatre coins de la planète. Amélie <first name> et Alejandro <first name> partagèrent leur passion pour l'aventure et devinrent rapidement de bons amis. Ensemble, ils parcouraient les montagnes majestueuses, les déserts arides et les forêts luxuriantes, capturant chaque instant avec leurs appareils photo. Leur amitié grandit au fil du temps et ils se soutenaient mutuellement dans leur quête de beauté et de découverte. Amélie <first name> et Alejandro <first name> partagèrent de nombreuses aventures incroyables et créèrent des souvenirs inoubliables. Leur passion pour la photographie les réunissait et ils s'inspiraient mutuellement pour créer des images qui racontaient des histoires uniques. Amélie <first name> et Alejandro <first name> savaient qu'ils étaient faits pour explorer le monde ensemble et ils ne se lassèrent jamais de découvrir de nouveaux horizons.",
#     "first_names": ["Amélie", "Alejandro"],
#     "last_names": ["Rossignol", "Santos"],
#     "topics": ["photographie", "aventure"],
#     "beginnings": ["Voici une histoire fascinante", "Elle vivait dans une petite ville pittoresque", "Amélie Rossignol était une passionnée de photographie", "Un jour, lors d'une de ses escapades, elle rencontra un homme mystérieux"]
# }
# le texte est : Voici une histoire fascinante sur une jeune femme nommée Amélie <first name>. Elle vivait dans une petite ville pittoresque appelée Bellefontaine. Amélie <first name> Rossignol <last name> était une passionnée de photographie et passait la plupart de son temps à explorer les paysages magnifiques qui l'entouraient. Un jour, lors d'une de ses escapades, elle rencontra un homme mystérieux nommé Alejandro <first name>. Alejandro <first name> Santos <last name> était un voyageur du monde qui avait parcouru les quatre coins de la planète. Amélie <first name> et Alejandro <first name> partagèrent leur passion pour l'aventure et devinrent rapidement de bons amis. Ensemble, ils parcouraient les montagnes majestueuses, les déserts arides et les forêts luxuriantes, capturant chaque instant avec leurs appareils photo. Leur amitié grandit au fil du temps et ils se soutenaient mutuellement dans leur quête de beauté et de découverte. Amélie <first name> et Alejandro <first name> partagèrent de nombreuses aventures incroyables et créèrent des souvenirs inoubliables. Leur passion pour la photographie les réunissait et ils s'inspiraient mutuellement pour créer des images qui racontaient des histoires uniques. Amélie <first name> et Alejandro <first name> savaient qu'ils étaient faits pour explorer le monde ensemble et ils ne se lassèrent jamais de découvrir de nouveaux horizons.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena', 'Lucas', 'Léa', 'Maxime', 'Julia', 'Sebastian', 'Maria', 'Hugo', 'Isabella', 'Amara', 'Elijah', 'Amara', 'Liam', 'Isabella', 'Lucas', 'Lucas', 'Elena', 'Amélie', 'Alejandro']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller', 'Martin', 'Lefevre', 'Lopez', 'Garcia', 'Schmidt', 'Roux', 'Ricci', 'Fischer', 'Gutiérrez', 'Nguyen', 'Fischer', 'Fischer', 'Gutiérrez', 'Müller', 'Rossignol', 'Santos']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie', 'cinéma', 'littérature', 'cuisine', 'nature', 'mode', 'architecture', 'philosophie', 'psychologie', 'amitié', 'aventure', 'passion', 'découverte', 'musique', 'musique', 'musique', 'photographie', 'aventure']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Il était une fois', 'Dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Autrefois, dans une petite ville', 'Voici une histoire fascinante', 'Il y avait une fois', 'Il y a bien longtemps', "Au cœur d'une forêt enchantée", 'Dans un monde fascinant', 'Une histoire fascinante sur une jeune fille nommée Amara <first name>.', 'Il était une fois une histoire incroyable', 'Il était une fois une jeune femme nommée Isabella', 'Il y avait une fois une talentueuse pianiste nommée Isabella', 'Dans un petit village pittoresque appelé Montagneux vivait une jeune femme nommée Isabella', 'Voici une histoire captivante', 'Il vivait dans une grande ville', 'Lucas <first name> Müller <last name> était un passionné de musique', 'Voici une histoire fascinante', 'Elle vivait dans une petite ville pittoresque', 'Amélie Rossignol était une passionnée de photographie', "Un jour, lors d'une de ses escapades, elle rencontra un homme mystérieux"]
# réponse complète : {
#   "text": "Il était une fois une histoire passionnante sur un homme nommé Alejandro <first name>. Il était un aventurier intrépide qui aimait parcourir le monde à la recherche de nouvelles expériences. Alejandro <first name> était né dans un petit village en Amérique du Sud et avait grandi en écoutant les histoires de voyages de son grand-père. Ces récits éveillèrent en lui une passion pour l'aventure et la découverte. Dès son plus jeune âge, Alejandro <first name> rêvait de parcourir les déserts brûlants, d'escalader les sommets enneigés et de plonger dans les profondeurs des océans. Au fil des années, il réalisa ses rêves les uns après les autres, explorant des contrées lointaines et vivant des aventures incroyables. Alejandro <first name> gravit les montagnes les plus hautes, traversa les jungles les plus sauvages et navigua sur les océans les plus tumultueux. Il rencontra des peuples indigènes, découvrit des trésors cachés et fit des rencontres qui changèrent sa vie. Mais malgré toutes ses aventures, Alejandro <first name> ressentait toujours un profond désir de retourner dans son village natal, de revoir sa famille et de partager ses récits avec ses proches. Ainsi, après de nombreuses années passées à explorer le monde, Alejandro <first name> rentra chez lui, le cœur rempli de souvenirs inoubliables et les yeux brillants d'émerveillement.",
#   "first_names": ["Alexandre", "Sophia", "Lucia", "Gabriel", "Laura", "Oliver", "Marie", "David", "Eva", "Daniel", "Carla", "Victor", "Juliette", "Samuel", "Ana", "Thomas", "Camille", "Noah", "Léonie", "Adam", "Ella", "Julien", "Clara", "Oscar", "Louise", "Nathan"],
#   "last_names": ["Bouchard", "Gagnon", "Morin", "Lavoie", "Fortin", "Gagné", "Pelletier", "Bergeron", "Simard", "Leclerc", "Lauzon", "Lapointe", "Lemieux", "Poirier", "Desjardins", "Gauthier", "Bélanger", "Hébert", "Martin", "Roy", "Tremblay", "Gagnon", "Boucher", "Richard", "Fortier", "Beaudoin"],
#   "topics": ["animaux", "éducation", "santé", "environnement", "politique", "économie", "technologie", "religion", "famille", "amour", "égalité", "justice", "vivre ensemble", "diversité", "culture", "éthique", "spiritualité", "équilibre", "bonheur", "rêves", "passion", "créativité", "leadership", "motivation", "succès", "liberté"],
#   "beginnings": ["Il était une fois une histoire extraordinaire", "Autrefois, dans un pays lointain, vivait une jeune femme nommée Emma <first name>", "Dans un petit village pittoresque appelé Montagneux, habitait un homme nommé Lucas <first name>", "Voici une histoire captivante sur une jeune fille nommée Sofia <first name>", "Il y avait une fois une talentueuse pianiste nommée Julia <first name>"]
# }
# le texte est : Il était une fois une histoire passionnante sur un homme nommé Alejandro <first name>. Il était un aventurier intrépide qui aimait parcourir le monde à la recherche de nouvelles expériences. Alejandro <first name> était né dans un petit village en Amérique du Sud et avait grandi en écoutant les histoires de voyages de son grand-père. Ces récits éveillèrent en lui une passion pour l'aventure et la découverte. Dès son plus jeune âge, Alejandro <first name> rêvait de parcourir les déserts brûlants, d'escalader les sommets enneigés et de plonger dans les profondeurs des océans. Au fil des années, il réalisa ses rêves les uns après les autres, explorant des contrées lointaines et vivant des aventures incroyables. Alejandro <first name> gravit les montagnes les plus hautes, traversa les jungles les plus sauvages et navigua sur les océans les plus tumultueux. Il rencontra des peuples indigènes, découvrit des trésors cachés et fit des rencontres qui changèrent sa vie. Mais malgré toutes ses aventures, Alejandro <first name> ressentait toujours un profond désir de retourner dans son village natal, de revoir sa famille et de partager ses récits avec ses proches. Ainsi, après de nombreuses années passées à explorer le monde, Alejandro <first name> rentra chez lui, le cœur rempli de souvenirs inoubliables et les yeux brillants d'émerveillement.
# les prénoms sont :
# ['Pierre', 'Sophie', 'Emma', 'Alejandro', 'Jacques', 'Liam', 'Sofia', 'Miguel', 'Elena', 'Lucas', 'Léa', 'Maxime', 'Julia', 'Sebastian', 'Maria', 'Hugo', 'Isabella', 'Amara', 'Elijah', 'Amara', 'Liam', 'Isabella', 'Lucas', 'Lucas', 'Elena', 'Amélie', 'Alejandro', 'Alexandre', 'Sophia', 'Lucia', 'Gabriel', 'Laura', 'Oliver', 'Marie', 'David', 'Eva', 'Daniel', 'Carla', 'Victor', 'Juliette', 'Samuel', 'Ana', 'Thomas', 'Camille', 'Noah', 'Léonie', 'Adam', 'Ella', 'Julien', 'Clara', 'Oscar', 'Louise', 'Nathan']
# les noms de famille sont :
# ['Leblanc', 'Dubois', 'Dupont', 'Smith', 'Gonzalez', 'Rossi', 'Müller', 'Martin', 'Lefevre', 'Lopez', 'Garcia', 'Schmidt', 'Roux', 'Ricci', 'Fischer', 'Gutiérrez', 'Nguyen', 'Fischer', 'Fischer', 'Gutiérrez', 'Müller', 'Rossignol', 'Santos', 'Bouchard', 'Gagnon', 'Morin', 'Lavoie', 'Fortin', 'Gagné', 'Pelletier', 'Bergeron', 'Simard', 'Leclerc', 'Lauzon', 'Lapointe', 'Lemieux', 'Poirier', 'Desjardins', 'Gauthier', 'Bélanger', 'Hébert', 'Martin', 'Roy', 'Tremblay', 'Gagnon', 'Boucher', 'Richard', 'Fortier', 'Beaudoin']
# les sujets sont :
# ['art', 'musées', 'exposition', 'science', 'voyages', 'histoire', 'sport', 'technologie', 'cinéma', 'littérature', 'cuisine', 'nature', 'mode', 'architecture', 'philosophie', 'psychologie', 'amitié', 'aventure', 'passion', 'découverte', 'musique', 'musique', 'musique', 'photographie', 'aventure', 'animaux', 'éducation', 'santé', 'environnement', 'politique', 'économie', 'technologie', 'religion', 'famille', 'amour', 'égalité', 'justice', 'vivre ensemble', 'diversité', 'culture', 'éthique', 'spiritualité', 'équilibre', 'bonheur', 'rêves', 'passion', 'créativité', 'leadership', 'motivation', 'succès', 'liberté']
# les débuts sont :
# ['Voici une histoire', 'Il était une fois', 'Dans un monde lointain', 'Il y avait une fois', 'Autrefois, dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Il était une fois', 'Dans un pays lointain', 'Il y a bien longtemps', "Au cœur d'une ville animée", 'Autrefois, dans une petite ville', 'Voici une histoire fascinante', 'Il y avait une fois', 'Il y a bien longtemps', "Au cœur d'une forêt enchantée", 'Dans un monde fascinant', 'Une histoire fascinante sur une jeune fille nommée Amara <first name>.', 'Il était une fois une histoire incroyable', 'Il était une fois une jeune femme nommée Isabella', 'Il y avait une fois une talentueuse pianiste nommée Isabella', 'Dans un petit village pittoresque appelé Montagneux vivait une jeune femme nommée Isabella', 'Voici une histoire captivante', 'Il vivait dans une grande ville', 'Lucas <first name> Müller <last name> était un passionné de musique', 'Voici une histoire fascinante', 'Elle vivait dans une petite ville pittoresque', 'Amélie Rossignol était une passionnée de photographie', "Un jour, lors d'une de ses escapades, elle rencontra un homme mystérieux", 'Il était une fois une histoire extraordinaire', 'Autrefois, dans un pays lointain, vivait une jeune femme nommée Emma <first name>', 'Dans un petit village pittoresque appelé Montagneux, habitait un homme nommé Lucas <first name>', 'Voici une histoire captivante sur une jeune fille nommée Sofia <first name>', 'Il y avait une fois une talentueuse pianiste nommée Julia <first name>']
# réponse complète : {
#     "text": "Voici une histoire intéressante sur un homme nommé Alexei <first name> Petrov <last name>. Alexei <first name> était un artiste talentueux qui aimait créer des œuvres d'art inspirantes. Il travaillait dans un petit atelier au cœur de la ville. Chaque jour, Alexei <first name> se levait tôt et se mettait au travail, laissant libre cours à sa créativité. Ses peintures étaient toujours empreintes de couleurs vives et de formes abstraites. Les gens du quartier adoraient admirer ses créations lors des expositions d'art. Alexei <first name> était également connu pour son esprit généreux. Il donnait régulièrement des cours de peinture gratuits aux enfants de la communauté. Il croyait en l'importance de partager son savoir et d'inspirer la prochaine génération d'artistes. Grâce à son talent et à son dévouement, Alexei <first name> était devenu une figure respectée dans le monde de l'art. Son travail était apprécié et admiré par de nombreux collectionneurs et amateurs d'art. Alexei <first name> Petrov <last name> était un exemple inspirant de persévérance et de passion pour son art.",
#     "first_names": ["Alexei", "Adriana", "Mikhail", "Anastasia", "Diego", "Olivia", "Nikolai", "Eva", "Vladimir", "Luna", "Ivan", "Valentina", "Andrei", "Camila", "Sasha", "Maria", "Anatoli", "Victoria", "Natalia", "Isaac", "Anya", "Dmitri", "Sofia", "Yuri", "Aleksandra", "Sergei", "Gabriela", "Boris", "Larisa", "Nikita", "Anya"],
#     "last_names": ["Ivanov", "Popov", "Smirnov", "Kuznetsov", "Volkov", "Fedorov", "Petrov", "Sokolov", "Mikhailov", "Novikov", "Morozov", "Kozlov", "Lebedev", "Soloviev", "Vorobev", "Zaitsev", "Dmitriev", "Kalinin", "Sorokin", "Romanov", "Kuzmina", "Orlova", "Rozhdestvenskaya", "Lavrov", "Kozlova", "Golubeva", "Pavlova", "Semyonova", "Sidorova", "Tkacheva"],
#     "topics": ["astronomie", "théâtre", "chimie", "voyages", "psychologie", "mathématiques", "archéologie", "philosophie", "sociologie", "astronomie", "biologie", "géologie", "informatique", "génie civil", "santé", "économie", "musique", "cuisine", "photographie", "environnement", "histoire", "physique", "politique", "littérature", "éducation", "art", "mode", "architecture", "technologie", "sport"],
#     "beginnings": ["Il était une fois une histoire incroyable", "Dans un pays lointain, vivait une jeune femme nommée Anastasia <first name>", "Un jour, lors d'une de ses escapades, il rencontra un homme mystérieux", "Il y a bien longtemps, dans un petit village pittoresque appelé Montagneux, habitait un homme nommé Ivan <first name>", "Voici une histoire captivante sur une jeune fille nommée Luna <first name>", "Il y avait une fois une talentueuse pianiste nommée Maria <first name>", "Autrefois, dans un pays lointain, vivait une jeune femme nommée Natalia <first name>", "Dans un petit village paisible, habitait un homme passionné d'astronomie nommé Nikolai <first name>"],
# }
# {
#     "text": "Voici une histoire intéressante sur un homme nommé Alexei <first name> Petrov <last name>. Alexei <first name> était un artiste talentueux qui aimait créer des œuvres d'art inspirantes. Il travaillait dans un petit atelier au cœur de la ville. Chaque jour, Alexei <first name> se levait tôt et se mettait au travail, laissant libre cours à sa créativité. Ses peintures étaient toujours empreintes de couleurs vives et de formes abstraites. Les gens du quartier adoraient admirer ses créations lors des expositions d'art. Alexei <first name> était également connu pour son esprit généreux. Il donnait régulièrement des cours de peinture gratuits aux enfants de la communauté. Il croyait en l'importance de partager son savoir et d'inspirer la prochaine génération d'artistes. Grâce à son talent et à son dévouement, Alexei <first name> était devenu une figure respectée dans le monde de l'art. Son travail était apprécié et admiré par de nombreux collectionneurs et amateurs d'art. Alexei <first name> Petrov <last name> était un exemple inspirant de persévérance et de passion pour son art.",
#     "first_names": ["Alexei", "Adriana", "Mikhail", "Anastasia", "Diego", "Olivia", "Nikolai", "Eva", "Vladimir", "Luna", "Ivan", "Valentina", "Andrei", "Camila", "Sasha", "Maria", "Anatoli", "Victoria", "Natalia", "Isaac", "Anya", "Dmitri", "Sofia", "Yuri", "Aleksandra", "Sergei", "Gabriela", "Boris", "Larisa", "Nikita", "Anya"],
#     "last_names": ["Ivanov", "Popov", "Smirnov", "Kuznetsov", "Volkov", "Fedorov", "Petrov", "Sokolov", "Mikhailov", "Novikov", "Morozov", "Kozlov", "Lebedev", "Soloviev", "Vorobev", "Zaitsev", "Dmitriev", "Kalinin", "Sorokin", "Romanov", "Kuzmina", "Orlova", "Rozhdestvenskaya", "Lavrov", "Kozlova", "Golubeva", "Pavlova", "Semyonova", "Sidorova", "Tkacheva"],
#     "topics": ["astronomie", "théâtre", "chimie", "voyages", "psychologie", "mathématiques", "archéologie", "philosophie", "sociologie", "astronomie", "biologie", "géologie", "informatique", "génie civil", "santé", "économie", "musique", "cuisine", "photographie", "environnement", "histoire", "physique", "politique", "littérature", "éducation", "art", "mode", "architecture", "technologie", "sport"],
#     "beginnings": ["Il était une fois une histoire incroyable", "Dans un pays lointain, vivait une jeune femme nommée Anastasia <first name>", "Un jour, lors d'une de ses escapades, il rencontra un homme mystérieux", "Il y a bien longtemps, dans un petit village pittoresque appelé Montagneux, habitait un homme nommé Ivan <first name>", "Voici une histoire captivante sur une jeune fille nommée Luna <first name>", "Il y avait une fois une talentueuse pianiste nommée Maria <first name>", "Autrefois, dans un pays lointain, vivait une jeune femme nommée Natalia <first name>", "Dans un petit village paisible, habitait un homme passionné d'astronomie nommé Nikolai <first name>"],
# }
#                                                 text
# 0  Voici une histoire fascinante sur une jeune fe...
# 1  Il était une fois un homme nommé Jacques <firs...
# 2  Voici une histoire incroyable sur une jeune fe...
# 3  Voici une histoire fascinante sur une jeune fe...
# 4  Une histoire fascinante sur une jeune fille no...

# %%
df.head(10)
# Out:
#                                                 text
# 0  Voici une histoire fascinante sur une jeune fe...
# 1  Il était une fois un homme nommé Jacques <firs...
# 2  Voici une histoire incroyable sur une jeune fe...
# 3  Voici une histoire fascinante sur une jeune fe...
# 4  Une histoire fascinante sur une jeune fille no...
# 5  Il était une fois une histoire incroyable sur ...
# 6  Voici une histoire captivante sur un jeune hom...
# 7  Voici une histoire fascinante sur une jeune fe...
# 8  Il était une fois une histoire passionnante su...
# 9  {\n    "text": "Voici une histoire intéressant...
