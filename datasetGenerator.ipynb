# %%
import pandas as pd
# create an empty dataframe with only one column named "text"
df = pd.DataFrame(columns=["text"])

# %%
# make a function to read a string in a variable and concatenate it to the dataframe
def add_to_df(text):
    global df
    df = pd.concat([df, pd.DataFrame([text], columns=["text"])], ignore_index=True)

# %%
#get openai api key from .env file
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# # modèle de fonctionnement des prompts avec un texte
# text = f"""
# You should express what you want a model to do by \ 
# providing instructions that are as clear and \ 
# specific as you can possibly make them. \ 
# This will guide the model towards the desired output, \ 
# and reduce the chances of receiving irrelevant \ 
# or incorrect responses. Don't confuse writing a \ 
# clear prompt with writing a short prompt. \ 
# In many cases, longer prompts provide more clarity \ 
# and context for the model, which can lead to \ 
# more detailed and relevant outputs.
# """
# prompt = f"""
# Summarize the text delimited by triple backticks \ 
# into a single sentence.
# ```{text}```
# """
# response = get_completion(prompt)
# print(response)

# %%
# # text generation
# prompt = f"""
# Génère un court texte en Français. \
# Une fois le texte généré, recherche tous les prénoms, noms de famille et noms d'entreprises dans ce texte. \
# Ajoute la mention <first name> après chaque occurrence de chaque prénom ; ajoute la mention <last name> après chaque occurrence de chaque nom de famille ; ajoute la mention mention <company name> après chaque occurrence de chaque nom d'entreprise."
# """
# response = get_completion(prompt)
# print(response)

# %%
# prompt = f"""
# Your task is to perform the actions described below:
# 1 - Generate a short text in French.
# 2 - Once generated, look for proper names.
# 3 - In the text from step 1, add the mention <first name> after each first name, add the mention <last name> after each last name.
# Here is an example of what the output should look like. Don't make your text about a similar topic or it will be rejected:
# ```
# Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
# ```
# """
# response = get_completion(prompt)
# print(response)

# %%
prompt = f"""
Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
```
Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
```
"""
response = get_completion(prompt)
add_to_df(response)
df.head()
# Out:
#                                                 text
# 0  Il était une fois dans un petit village pittor...

# %%
# a function that make the prompt from two lists of first names and last names
def makePrompt(first_names,last_names,topic,style,beginning):
    prompt = f"""
    Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
    Here is an example of what the output should look like. The topic, tone, and style of the text should be different from the example below:
    ```
    Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
    ```
    The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
    the first names should be different from the following list: {first_names}
    the last names should be different from the following list: {last_names}
    the topic should be different from the following list: {topic}
    the style should be different from the following list: {style}
    the beginning should be different from the following list: {beginning}
    Here are a few suggestions of topics: judiciaire, politique, sport, économie, santé, culture, technologie, environnement, éducation, société, international, sciences, médias, religion, faits divers, people, etc.
    Here are few suggestions of styles: informatif, narratif, descriptif, argumentatif, explicatif, injonctif, poétique, humoristique, etc.
    The output should be a JSON object with the following keys: text, first_names, last_names, topics, styles, beginnings.
    """
    return prompt

# %%
def makePrompt(first_names,last_names,topic,literary_genre,beginning):
    prompt = f"""
    Your task is to a short text in French where first names and last names are followed by the mention <first name> and <last name> respectively.
    the first names should be different from the following list: {first_names}
    the last names should be different from the following list: {last_names}
    the topic should be different from the following list: {topic}
    the literary genre should be different from the following list: {literary_genre}
    the beginning should be different from the following list: {beginning}
    Here is an example of what the output should look like. The topic, tone, and literary genre of the text should be different from the example below:
    ```
    Voici une histoire passionnante sur un jeune garçon nommé Pierre <prénom>. Il vivait dans un petit village appelé Saint-Étienne <nom de famille>. Pierre <prénom> aimait explorer la nature et passer du temps avec ses amis. Un jour, il rencontra une fille charmante nommée Sophie <prénom>. Ils devinrent rapidement les meilleurs amis. Pierre <prénom> et Sophie <prénom> passaient leurs journées à jouer dans les champs et à rire ensemble. Cependant, un jour, Pierre <prénom> tomba malade et Sophie <prénom> fut très inquiète. Heureusement, grâce aux soins attentifs de sa famille et des médecins, Pierre <prénom> se rétablit rapidement. Sophie <prénom> était soulagée de voir son ami en bonne santé. Depuis ce jour, Pierre <prénom> et Sophie <prénom> étaient inséparables et partageaient de nombreux moments de bonheur ensemble.
    ```
    The names should be as varied as possible, including foreign names. The topic could be about anything, but it should be different from the example above.
    The output should be a JSON object with the following keys: text, first_names, last_names, topics, literary_genres, beginnings.
    """
    return prompt

# %%
import json
first_names = ["Pierre"]
last_names = ["Saint-Étienne"]
topic = []
literary_genre = []
beginning = ["Voici une histoire"]

# %%
# add texts in a loop to dataframe
for i in range(10):
    prompt = makePrompt(first_names,last_names,topic,literary_genre,beginning)
    response = get_completion(prompt)
    print(response)
    response = json.loads(response)
    text = response["text"]
    print(text)
    # get the contents of the "first_names" and "last_names" keys from the JSON object in the response and append them to the lists
    first_names = first_names + response["first_names"]
    last_names = last_names + response["last_names"]
    topic = topic + response["topics"]
    literary_genre = literary_genre + response["literary_genres"]
    beginning = beginning + response["beginnings"]
    print(first_names)
    print(last_names)
    print(topic)
    print(literary_genre)
    print(beginning)


    add_to_df(text)

df.head()
# Out:
# {
#     "text": "Voici une histoire fascinante sur une jeune femme nommée Emma <prénom>. Elle vivait dans une grande ville appelée Martinez <nom de famille>. Emma <prénom> était une artiste talentueuse et passionnée par la peinture. Elle passait des heures dans son atelier, créant des œuvres d'art magnifiques et expressives. Un jour, Emma <prénom> fut invitée à exposer ses peintures dans une galerie d'art renommée. C'était une occasion excitante pour elle de partager son talent avec le monde entier. L'exposition fut un grand succès et les critiques saluèrent le style unique et la créativité d'Emma <prénom>. Elle devint rapidement une artiste célèbre et admirée. Malgré sa renommée, Emma <prénom> resta humble et dévouée à son art. Elle continuait à peindre avec passion et à inspirer les autres par sa vision artistique. Aujourd'hui, les œuvres d'Emma <prénom> sont exposées dans les plus grands musées du monde, et son héritage artistique perdure.",
#     "first_names": ["Emma"],
#     "last_names": ["Martinez"],
#     "topics": ["Art"],
#     "literary_genres": [],
#     "beginnings": []
# }
# Voici une histoire fascinante sur une jeune femme nommée Emma <prénom>. Elle vivait dans une grande ville appelée Martinez <nom de famille>. Emma <prénom> était une artiste talentueuse et passionnée par la peinture. Elle passait des heures dans son atelier, créant des œuvres d'art magnifiques et expressives. Un jour, Emma <prénom> fut invitée à exposer ses peintures dans une galerie d'art renommée. C'était une occasion excitante pour elle de partager son talent avec le monde entier. L'exposition fut un grand succès et les critiques saluèrent le style unique et la créativité d'Emma <prénom>. Elle devint rapidement une artiste célèbre et admirée. Malgré sa renommée, Emma <prénom> resta humble et dévouée à son art. Elle continuait à peindre avec passion et à inspirer les autres par sa vision artistique. Aujourd'hui, les œuvres d'Emma <prénom> sont exposées dans les plus grands musées du monde, et son héritage artistique perdure.
# ['Pierre', 'Emma']
# ['Saint-Étienne', 'Martinez']
# ['Art']
# []
# ['Voici une histoire']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle vivait dans une petite ville appelée Martinez <nom de famille>. Emma <prénom> était une passionnée de musique et elle passait la plupart de son temps à jouer du piano. Un jour, elle rencontra un homme mystérieux nommé Alejandro <prénom>. Alejandro <prénom> était un talentueux guitariste et ils se lièrent d'amitié instantanément. Ensemble, ils formèrent un groupe de musique et commencèrent à se produire dans les bars locaux. Leur musique était si captivante qu'ils attirèrent rapidement l'attention d'un producteur de musique renommé. Grâce à leur talent et à leur détermination, Emma <prénom> et Alejandro <prénom> devinrent des stars de la scène musicale. Ils parcoururent le monde entier, jouant devant des milliers de fans. Malgré leur succès, Emma <prénom> et Alejandro <prénom> restèrent humbles et reconnaissants pour toutes les opportunités qui leur étaient offertes. Ils savaient que leur amitié et leur passion pour la musique étaient les clés de leur réussite.",
#     "first_names": ["Emma", "Alejandro"],
#     "last_names": ["Martinez"],
#     "topics": ["Musique"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle vivait dans une petite ville appelée Martinez <nom de famille>. Emma <prénom> était une passionnée de musique et elle passait la plupart de son temps à jouer du piano. Un jour, elle rencontra un homme mystérieux nommé Alejandro <prénom>. Alejandro <prénom> était un talentueux guitariste et ils se lièrent d'amitié instantanément. Ensemble, ils formèrent un groupe de musique et commencèrent à se produire dans les bars locaux. Leur musique était si captivante qu'ils attirèrent rapidement l'attention d'un producteur de musique renommé. Grâce à leur talent et à leur détermination, Emma <prénom> et Alejandro <prénom> devinrent des stars de la scène musicale. Ils parcoururent le monde entier, jouant devant des milliers de fans. Malgré leur succès, Emma <prénom> et Alejandro <prénom> restèrent humbles et reconnaissants pour toutes les opportunités qui leur étaient offertes. Ils savaient que leur amitié et leur passion pour la musique étaient les clés de leur réussite.
# ['Pierre', 'Emma', 'Emma', 'Alejandro']
# ['Saint-Étienne', 'Martinez', 'Martinez']
# ['Art', 'Musique']
# []
# ['Voici une histoire', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la science et rêvait de devenir astronaute. Emma <prénom> était déterminée à repousser les limites de l'exploration spatiale et à découvrir de nouveaux mondes. Elle passait des heures à étudier les étoiles et à se familiariser avec les différentes missions spatiales. Un jour, Emma <prénom> fut sélectionnée pour faire partie d'une équipe de scientifiques qui travaillaient sur un projet révolutionnaire. Ils avaient pour mission de construire une station spatiale avancée qui permettrait aux humains de vivre sur d'autres planètes. Emma <prénom> était excitée par cette opportunité et travaillait sans relâche pour mener à bien sa mission. Après des mois de travail acharné, la station spatiale fut enfin terminée. Emma <prénom> et son équipe étaient fiers de leur réalisation et se préparaient à partir pour leur première mission. Ils s'envolèrent vers une planète lointaine et commencèrent à explorer son environnement unique. Emma <prénom> était émerveillée par la beauté de cette planète inconnue et était déterminée à en apprendre davantage. Elle collectait des échantillons, prenait des mesures et documentait tout ce qu'elle découvrait. Au fil du temps, Emma <prénom> devint une experte en exploration spatiale et ses découvertes contribuèrent grandement à l'avancement de la science. Elle était une source d'inspiration pour de nombreux jeunes qui rêvaient de suivre ses traces. Emma <prénom> était fière de son parcours et savait qu'elle avait réalisé son rêve d'enfant.",
#     "first_names": ["Emma"],
#     "last_names": ["Saint-Étienne"],
#     "topics": ["Science"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la science et rêvait de devenir astronaute. Emma <prénom> était déterminée à repousser les limites de l'exploration spatiale et à découvrir de nouveaux mondes. Elle passait des heures à étudier les étoiles et à se familiariser avec les différentes missions spatiales. Un jour, Emma <prénom> fut sélectionnée pour faire partie d'une équipe de scientifiques qui travaillaient sur un projet révolutionnaire. Ils avaient pour mission de construire une station spatiale avancée qui permettrait aux humains de vivre sur d'autres planètes. Emma <prénom> était excitée par cette opportunité et travaillait sans relâche pour mener à bien sa mission. Après des mois de travail acharné, la station spatiale fut enfin terminée. Emma <prénom> et son équipe étaient fiers de leur réalisation et se préparaient à partir pour leur première mission. Ils s'envolèrent vers une planète lointaine et commencèrent à explorer son environnement unique. Emma <prénom> était émerveillée par la beauté de cette planète inconnue et était déterminée à en apprendre davantage. Elle collectait des échantillons, prenait des mesures et documentait tout ce qu'elle découvrait. Au fil du temps, Emma <prénom> devint une experte en exploration spatiale et ses découvertes contribuèrent grandement à l'avancement de la science. Elle était une source d'inspiration pour de nombreux jeunes qui rêvaient de suivre ses traces. Emma <prénom> était fière de son parcours et savait qu'elle avait réalisé son rêve d'enfant.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne']
# ['Art', 'Musique', 'Science']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la danse et rêvait de devenir une célèbre danseuse. Emma <prénom> s'entraînait tous les jours avec détermination et persévérance. Un jour, elle eut l'opportunité de participer à une compétition internationale de danse. Elle était excitée et nerveuse à la fois. Pendant la compétition, Emma <prénom> dansa avec grâce et émotion, captivant le public et les juges. À la fin de la compétition, elle remporta la première place et réalisa son rêve de devenir une danseuse renommée. Emma <prénom> était comblée de bonheur et remercia tous ceux qui l'avaient soutenue dans son parcours. Depuis ce jour, Emma <prénom> continua de danser avec passion et inspira de nombreux autres danseurs à poursuivre leurs rêves.",
#     "first_names": ["Emma"],
#     "last_names": ["Saint-Étienne"],
#     "topics": ["Danse"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la danse et rêvait de devenir une célèbre danseuse. Emma <prénom> s'entraînait tous les jours avec détermination et persévérance. Un jour, elle eut l'opportunité de participer à une compétition internationale de danse. Elle était excitée et nerveuse à la fois. Pendant la compétition, Emma <prénom> dansa avec grâce et émotion, captivant le public et les juges. À la fin de la compétition, elle remporta la première place et réalisa son rêve de devenir une danseuse renommée. Emma <prénom> était comblée de bonheur et remercia tous ceux qui l'avaient soutenue dans son parcours. Depuis ce jour, Emma <prénom> continua de danser avec passion et inspira de nombreux autres danseurs à poursuivre leurs rêves.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Emma']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne', 'Saint-Étienne']
# ['Art', 'Musique', 'Science', 'Danse']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la danse <nom de famille> et rêvait de devenir une célèbre danseuse. Emma <prénom> passait des heures à s'entraîner et à perfectionner ses mouvements. Un jour, elle eut l'opportunité de participer à un concours de danse prestigieux. Emma <prénom> était à la fois excitée et nerveuse à l'idée de se produire devant un public nombreux. Elle travailla dur et se prépara intensément pour le grand jour. Lorsque le moment arriva, Emma <prénom> monta sur scène et dansa avec grâce et passion. Son talent et sa détermination furent récompensés, car elle remporta le premier prix du concours. Emma <prénom> était aux anges et réalisa enfin son rêve de devenir une danseuse professionnelle. Depuis ce jour, elle continua à se produire sur de grandes scènes du monde entier et inspira de nombreux jeunes danseurs avec son talent exceptionnel.",
#     "first_names": ["Emma"],
#     "last_names": ["Danse"],
#     "topics": ["Danse"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la danse <nom de famille> et rêvait de devenir une célèbre danseuse. Emma <prénom> passait des heures à s'entraîner et à perfectionner ses mouvements. Un jour, elle eut l'opportunité de participer à un concours de danse prestigieux. Emma <prénom> était à la fois excitée et nerveuse à l'idée de se produire devant un public nombreux. Elle travailla dur et se prépara intensément pour le grand jour. Lorsque le moment arriva, Emma <prénom> monta sur scène et dansa avec grâce et passion. Son talent et sa détermination furent récompensés, car elle remporta le premier prix du concours. Emma <prénom> était aux anges et réalisa enfin son rêve de devenir une danseuse professionnelle. Depuis ce jour, elle continua à se produire sur de grandes scènes du monde entier et inspira de nombreux jeunes danseurs avec son talent exceptionnel.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Emma', 'Emma']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne', 'Saint-Étienne', 'Danse']
# ['Art', 'Musique', 'Science', 'Danse', 'Danse']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <nom de famille> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle eut l'opportunité de participer à un concours de talents. Emma <prénom> était à la fois excitée et nerveuse à l'idée de monter sur scène devant un public. Mais elle se souvint des paroles de sa mère qui lui disait toujours de croire en elle-même. Le jour du concours arriva et Emma <prénom> donna une performance incroyable. Sa voix était puissante et émouvante, et le public était captivé. À la fin de sa chanson, Emma <prénom> reçut une standing ovation et remporta le concours. Elle réalisa enfin son rêve de devenir une chanteuse célèbre. Depuis ce jour, Emma <prénom> a enregistré plusieurs albums à succès et continue d'inspirer les autres avec sa musique.",
#     "first_names": ["Emma"],
#     "last_names": ["Musique"],
#     "topics": ["Chant"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <nom de famille> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle eut l'opportunité de participer à un concours de talents. Emma <prénom> était à la fois excitée et nerveuse à l'idée de monter sur scène devant un public. Mais elle se souvint des paroles de sa mère qui lui disait toujours de croire en elle-même. Le jour du concours arriva et Emma <prénom> donna une performance incroyable. Sa voix était puissante et émouvante, et le public était captivé. À la fin de sa chanson, Emma <prénom> reçut une standing ovation et remporta le concours. Elle réalisa enfin son rêve de devenir une chanteuse célèbre. Depuis ce jour, Emma <prénom> a enregistré plusieurs albums à succès et continue d'inspirer les autres avec sa musique.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Emma', 'Emma', 'Emma']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne', 'Saint-Étienne', 'Danse', 'Musique']
# ['Art', 'Musique', 'Science', 'Danse', 'Danse', 'Chant']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <nom de famille> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle eut l'opportunité de participer à un concours de talents. Emma <prénom> était à la fois excitée et nerveuse à l'idée de monter sur scène devant un public. Mais elle savait que c'était sa chance de réaliser son rêve. Le jour du concours arriva et Emma <prénom> se produisit avec passion et émotion. Sa voix magnifique et sa présence sur scène captivèrent le public. À la fin de sa performance, Emma <prénom> reçut une standing ovation et remporta le concours. C'était le début d'une carrière prometteuse pour Emma <prénom>. Elle signa un contrat avec une maison de disques et commença à enregistrer son premier album. Emma <prénom> était fière de voir son rêve se réaliser et était reconnaissante envers tous ceux qui l'avaient soutenue. Elle continua à travailler dur et à partager sa passion pour la musique avec le monde entier.",
#     "first_names": ["Emma"],
#     "last_names": ["Musique"],
#     "topics": ["Carrière musicale"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <nom de famille> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle eut l'opportunité de participer à un concours de talents. Emma <prénom> était à la fois excitée et nerveuse à l'idée de monter sur scène devant un public. Mais elle savait que c'était sa chance de réaliser son rêve. Le jour du concours arriva et Emma <prénom> se produisit avec passion et émotion. Sa voix magnifique et sa présence sur scène captivèrent le public. À la fin de sa performance, Emma <prénom> reçut une standing ovation et remporta le concours. C'était le début d'une carrière prometteuse pour Emma <prénom>. Elle signa un contrat avec une maison de disques et commença à enregistrer son premier album. Emma <prénom> était fière de voir son rêve se réaliser et était reconnaissante envers tous ceux qui l'avaient soutenue. Elle continua à travailler dur et à partager sa passion pour la musique avec le monde entier.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Emma', 'Emma', 'Emma', 'Emma']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne', 'Saint-Étienne', 'Danse', 'Musique', 'Musique']
# ['Art', 'Musique', 'Science', 'Danse', 'Danse', 'Chant', 'Carrière musicale']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la science <topic> et passait son temps à faire des expériences dans son laboratoire. Emma <prénom> était connue pour ses découvertes révolutionnaires dans le domaine de la médecine. Un jour, elle rencontra un homme charmant nommé Alejandro <prénom>. Alejandro <prénom> était un artiste talentueux qui se spécialisait dans la danse <topic>. Ils tombèrent amoureux et commencèrent à collaborer sur des projets mêlant la science et l'art. Leur travail innovant attira l'attention du monde entier et ils devinrent célèbres dans leurs domaines respectifs. Emma <prénom> et Alejandro <prénom> étaient un couple puissant et inspirant, montrant au monde que la science et l'art pouvaient se compléter mutuellement. Leur histoire est un exemple de passion, de créativité et de collaboration.",
#     "first_names": ["Emma", "Alejandro"],
#     "last_names": ["Saint-Étienne", "Martinez"],
#     "topics": ["Science", "Danse"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois", "Voici une histoire"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la science <topic> et passait son temps à faire des expériences dans son laboratoire. Emma <prénom> était connue pour ses découvertes révolutionnaires dans le domaine de la médecine. Un jour, elle rencontra un homme charmant nommé Alejandro <prénom>. Alejandro <prénom> était un artiste talentueux qui se spécialisait dans la danse <topic>. Ils tombèrent amoureux et commencèrent à collaborer sur des projets mêlant la science et l'art. Leur travail innovant attira l'attention du monde entier et ils devinrent célèbres dans leurs domaines respectifs. Emma <prénom> et Alejandro <prénom> étaient un couple puissant et inspirant, montrant au monde que la science et l'art pouvaient se compléter mutuellement. Leur histoire est un exemple de passion, de créativité et de collaboration.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Emma', 'Emma', 'Emma', 'Emma', 'Emma', 'Alejandro']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne', 'Saint-Étienne', 'Danse', 'Musique', 'Musique', 'Saint-Étienne', 'Martinez']
# ['Art', 'Musique', 'Science', 'Danse', 'Danse', 'Chant', 'Carrière musicale', 'Science', 'Danse']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Voici une histoire']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <topic> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle rencontra un jeune homme nommé Alejandro <prénom>. Alejandro <prénom> était un talentueux musicien et ils décidèrent de former un groupe ensemble. Ils passaient leurs journées à répéter et à écrire de nouvelles chansons. Leur musique <topic> était unique et captivante, et bientôt ils attirèrent l'attention d'un producteur de musique. Grâce à leur talent et à leur détermination, Emma <prénom> et Alejandro <prénom> signèrent un contrat d'enregistrement et leur carrière musicale <topic> décolla. Ils parcoururent le monde, donnant des concerts et partageant leur passion avec leurs fans. Emma <prénom> et Alejandro <prénom> étaient heureux de réaliser leur rêve et de vivre de leur passion pour la musique <topic>.",
#     "first_names": ["Emma", "Alejandro"],
#     "last_names": ["Saint-Étienne", "Martinez"],
#     "topics": ["Musique"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <topic> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle rencontra un jeune homme nommé Alejandro <prénom>. Alejandro <prénom> était un talentueux musicien et ils décidèrent de former un groupe ensemble. Ils passaient leurs journées à répéter et à écrire de nouvelles chansons. Leur musique <topic> était unique et captivante, et bientôt ils attirèrent l'attention d'un producteur de musique. Grâce à leur talent et à leur détermination, Emma <prénom> et Alejandro <prénom> signèrent un contrat d'enregistrement et leur carrière musicale <topic> décolla. Ils parcoururent le monde, donnant des concerts et partageant leur passion avec leurs fans. Emma <prénom> et Alejandro <prénom> étaient heureux de réaliser leur rêve et de vivre de leur passion pour la musique <topic>.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Emma', 'Emma', 'Emma', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Alejandro']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne', 'Saint-Étienne', 'Danse', 'Musique', 'Musique', 'Saint-Étienne', 'Martinez', 'Saint-Étienne', 'Martinez']
# ['Art', 'Musique', 'Science', 'Danse', 'Danse', 'Chant', 'Carrière musicale', 'Science', 'Danse', 'Musique']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Voici une histoire', 'Il était une fois']
# {
#     "text": "Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <topic> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle rencontra un jeune homme nommé Alejandro <prénom>. Alejandro <prénom> était un talentueux musicien et ils décidèrent de former un groupe ensemble. Ensemble, ils créèrent de magnifiques mélodies et se produisirent dans de nombreux concerts. Leur carrière musicale <topic> prit rapidement de l'ampleur et ils devinrent célèbres dans le monde entier. Emma <prénom> et Alejandro <prénom> étaient heureux de réaliser leur rêve et de partager leur passion pour la musique <topic> avec leurs fans. Ils continuèrent à créer de la musique <topic> inspirante et à vivre des aventures incroyables tout au long de leur carrière <topic>.",
#     "first_names": ["Emma", "Alejandro"],
#     "last_names": ["Saint-Étienne", "Martinez"],
#     "topics": ["Musique", "Carrière musicale"],
#     "literary_genres": [],
#     "beginnings": ["Il était une fois", "Voici une histoire"]
# }
# Il était une fois une jeune femme nommée Emma <prénom>. Elle était passionnée par la musique <topic> et rêvait de devenir une célèbre chanteuse. Emma <prénom> passait des heures à s'entraîner et à composer ses propres chansons. Un jour, elle rencontra un jeune homme nommé Alejandro <prénom>. Alejandro <prénom> était un talentueux musicien et ils décidèrent de former un groupe ensemble. Ensemble, ils créèrent de magnifiques mélodies et se produisirent dans de nombreux concerts. Leur carrière musicale <topic> prit rapidement de l'ampleur et ils devinrent célèbres dans le monde entier. Emma <prénom> et Alejandro <prénom> étaient heureux de réaliser leur rêve et de partager leur passion pour la musique <topic> avec leurs fans. Ils continuèrent à créer de la musique <topic> inspirante et à vivre des aventures incroyables tout au long de leur carrière <topic>.
# ['Pierre', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Emma', 'Emma', 'Emma', 'Emma', 'Emma', 'Alejandro', 'Emma', 'Alejandro', 'Emma', 'Alejandro']
# ['Saint-Étienne', 'Martinez', 'Martinez', 'Saint-Étienne', 'Saint-Étienne', 'Danse', 'Musique', 'Musique', 'Saint-Étienne', 'Martinez', 'Saint-Étienne', 'Martinez', 'Saint-Étienne', 'Martinez']
# ['Art', 'Musique', 'Science', 'Danse', 'Danse', 'Chant', 'Carrière musicale', 'Science', 'Danse', 'Musique', 'Musique', 'Carrière musicale']
# []
# ['Voici une histoire', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Il était une fois', 'Voici une histoire', 'Il était une fois', 'Il était une fois', 'Voici une histoire']
#                                                 text
# 0  Il était une fois dans un petit village pittor...
# 1  Voici une histoire fascinante sur un jeune hom...
# 2  Voici une histoire fascinante sur une jeune fe...
# 3  Voici une histoire fascinante sur une jeune fe...
# 4  Dans le domaine de la technologie, il y a un h...

# %%
df.head(10)
# Out:
#                                                 text
# 0  Il était une fois dans un petit village pittor...
# 1  Voici une histoire fascinante sur un jeune hom...
# 2  Voici une histoire fascinante sur une jeune fe...
# 3  Voici une histoire fascinante sur une jeune fe...
# 4  Dans le domaine de la technologie, il y a un h...
# 5  Il était une fois dans un petit village appelé...
# 6  Il était une fois dans un petit village appelé...
